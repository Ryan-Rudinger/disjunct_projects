# %% [markdown]
# # Homework 4
# ## Ryan Rudinger & Julia Jofe

# %%
# infamous imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import networkx as nx
import string

# %%
# read that file, doe
df = pd.read_csv("twitter_enviroed.csv")
df.head()
# Out:
#       Date       Screen Name         Full Name  \
# 0  3/15/16    @_Lightscap3s_              Otis
# 1  3/21/16    @_Lightscap3s_              Otis
# 2   4/6/16  @_Lindsay_Conway           Lindsay
# 3  3/23/16     @_mcisneros19  Mirella Cisneros
# 4  3/23/16     @_mcisneros19  Mirella Cisneros
#
#                                           Tweet Text      Tweet ID  \
# 0  RT @NatureBridge: "NatureBridge is Highlight o...  7.100000e+17
# 1  RT @NatureBridge: By 2050 we want more fish th...  7.120000e+17
# 2  RT @savageducates: Greenest School on #Earth s...  7.180000e+17
# 3  A1: For math children could measure trunks to ...  7.130000e+17
# 4  A2: Going outside & letting children find the ...  7.130000e+17
#
#                   App  Followers  Follows  Retweets  Favorites Verfied  \
# 0           RoundTeam       2644    590.0         1          0      No
# 1           RoundTeam       2641    587.0         2          0      No
# 2  Twitter for iPhone        164    318.0         2          0      No
# 3           TweetDeck          8     44.0         0          0      No
# 4           TweetDeck          8     44.0         0          0      No
#
#   User Since              Location  \
# 0     6/8/09            Carmel, IN
# 1     6/8/09            Carmel, IN
# 2     6/7/14  Bratislava, Slovakia
# 3     2/4/16                   NaN
# 4     2/4/16                   NaN
#
#                                                  Bio Profile Image
# 0  Artist @ Framed Lightscap3s LLC | Landscape, M...          View
# 1  Artist @ Framed Lightscap3s LLC | Landscape, M...          View
# 2  International education. SEN interests. Adopti...          View
# 3                                                NaN          View
# 4                                                NaN          View

# %% [markdown]
# What are your observations about how often the various apps (e.g., TweetDeck, Twitter for iPhone) are used to tweet? Show a visualization.

# %%
# Visualize
fig = plt.figure(figsize=(12,4))
df['App'].value_counts().plot(kind='bar')
plt.xlabel('App')
plt.ylabel('Number of Users')
plt.title('Number of Users per App')
plt.show()

# %% [markdown]
# Reflection:
#
# Only a few apps are really important. The most frequently used apps are Twitter for iPhone, Twitter Web Client, TweetDeck, Twitter for iPad, and Twitter for Android. An interesting observation is that while the top application is for iPhone users (typically seen as a Millenial and Gen Z product), the second application is Twitter Web Client, which is known for its popularity amongst older users because of its simpler interface. Another observation is that people are mainly using a combination of Apple softwares/products or operating from a Desktop before using Twitter on an Android.

# %% [markdown]
# What are your observations about how many original tweets there are compared to retweets (original contributions vs. amplification of others)? (Note that retweets start with the text RT and a username that starts with @.) Show a visualization.

# %%
tweets_df = df[['Screen Name','Tweet Text']]
rt_mask = []

for tweet in tweets_df['Tweet Text']:
    is_rt = tweet[:4] == 'RT @'
    rt_mask.append(is_rt)
retweets = tweets_df[rt_mask]
print('Visualization:\n\n', retweets)
# Out:
# Visualization:
#
#             Screen Name                                         Tweet Text
# 0       @_Lightscap3s_  RT @NatureBridge: "NatureBridge is Highlight o...
# 1       @_Lightscap3s_  RT @NatureBridge: By 2050 we want more fish th...
# 2     @_Lindsay_Conway  RT @savageducates: Greenest School on #Earth s...
# 20           @_swatik_  RT @EnviroEducators: Interested in environment...
# 21            @_withah  RT @ItsAboutTimeEDU: Scientists mimic Mars soi...
# 22           @02Benson  RT @GreeningForward: Our CEO @COrgbon is still...
# 23         @109ThornKs  RT @RangerRidley: The Outdoors. The Ultimate #...
# 24         @1915Aurora  RT @JasonSohigian: Our new #GetRooted video ju...
# 25         @1915Aurora  RT @ArmeniaTree: Check out our new 9-minute #y...
# 26     @1GratefulWorld  RT @CNC90: K's and Gr.8's come together to tal...
# 27         @1stof7gens  RT @GEOEC: AB Climate Leadership with @RachelN...
# 28         @1stof7gens  RT @AlbertaEE: Student are producing a white p...
# 29       @2015_Project  RT @ArmeniaTree: ATP Scales Up Environmental E...
# 30             @22C0in  RT @EPA: Teachers - are you thinking about #Ea...
# 39       @3PennyMovies  RT @Sierra_BC: Learn about the grasslands of t...
# 40      @3wlittlefalls  RT @MahaffyStars: Next week! @3wlittlefalls @j...
# 42             @500eco  RT @EPA: Teachers - are you thinking about #Ea...
# 43          @5intadewi  RT @EnviroEducators: Interested in environment...
# 44        @6Veronicadr  RT @MHEducation: "One touch of nature makes th...
# 45         @A_Dobbie11  RT @KinderKids123: Enjoyed our Skype read-alou...
# 46         @A_Dobbie11  RT @RangerRidley: #peel21st Wetlands Study @GW...
# 47          @AACPS_PGD  RT @MindShiftKQED: 5 @TED_ED Lessons to watch ...
# 48       @AAPCA_States  RT @EPA: #EnviroEd teachers: Apply for our env...
# 49       @AAPCA_States  RT @EPA: #EnviroEd teachers: Apply for our env...
# 52         @AAPremlall  RT @SustyQ: Thank you @RangerRidley! #enviroed...
# 54         @AAPremlall  RT @SustyQ: Awesome happenings with our friend...
# 56         @AAPremlall  RT @RangerRidley: Join #EnviroEd at the top of...
# 57         @AAPremlall  RT @RangerRidley: #EnviroEd chat is evolving h...
# 60         @AAPremlall  RT @SustyQ: We love Stephen + Lizette Ritz of ...
# 62         @AAPremlall  RT @RangerRidley: Thinking about #EnviroEd exp...
# ...                ...                                                ...
# 5479         @YES21stC  RT @MikeBartlettEdu: Hi Brandi! Guys meet our ...
# 5480         @YES21stC  RT @BrewongleEEC: Are you ready for the 2nd Au...
# 5481         @YES21stC  RT @EZECNSW: Have you completed an Ecological ...
# 5482      @ymahdessian  RT @ArmeniaTree: Check out our new 9-minute #y...
# 5483  @YorkUScientists  RT @gladyswlkong: Dendrochronologyband learnin...
# 5484      @YosemiteNPS  RT @NatureBridge: Are you a young woman 15-18 ...
# 5487      @youthdotgov  RT @EPA: Teachers - are you thinking about #Ea...
# 5488      @youthdotgov  RT @EPA: We're looking for #EnviroEd professio...
# 5489      @youthdotgov  RT @EPA: Applications for our #EnviroEd award ...
# 5490      @youthdotgov  RT @EPA: Know a K-12 #EnviroEd teacher setting...
# 5491      @youthdotgov  RT @EPA: #EnviroEd teachers: Apply for our env...
# 5492  @youthwavemakers  RT @PaulKelba: #yycbe #abed -fab #enviroed sum...
# 5494  @YRDSBEcoSchools  RT @EnviroEducators: Here's a clearer #EnviroE...
# 5495  @YRDSBEcoSchools  RT @EnviroEducators: National Wildlife Week is...
# 5496      @YRDSBGetOut  RT @MsPizzolon: #EcoClub #EarlyAct @YRDSBGetOu...
# 5497      @YukonEvents  RT @BeWildON: RT to show you care for Ontario'...
# 5498      @YuppieCuntx  RT @EPA: #EEWeek 2016 focuses on Greening STEM...
# 5499      @YuppieCuntx  RT @EPA: We're looking for #EnviroEd professio...
# 5500      @YuppieCuntx  RT @EPA: Know a K-12 #EnviroEd teacher setting...
# 5501      @YuppieCuntx  RT @EPA: Applications for our #EnviroEd award ...
# 5502      @YuppieCuntx  RT @EPA: #EnviroEd teachers: Apply for our env...
# 5503   @yycbike2school  RT @doctormorrison: This is key. #EnviroEd htt...
# 5504   @yycbike2school  RT @KinderFynes: A3: when kids aren't allowed ...
# 5505      @zeiss_micro  RT @PlanktonPundit: 👍 100% of Goodreads reader...
# 5506   @ZeroSumGameNOT  RT @EPA: We're looking for #EnviroEd professio...
# 5507       @zoebadcock  RT @EPA: We're looking for #EnviroEd professio...
# 5508          @ZoeWeil  RT @AAPremlall: A Generation of #Solutionaries...
# 5509          @ZohrinM  RT @RangerRidley: Today mind was reopened when...
# 5510      @ZwartblesIE  RT @AAPremlall: Native #Bees of Eastern North ...
# 5511           @zwaste  RT @EPAregion2: K-12 educators using innovativ...
#
# [2532 rows x 2 columns]

# %%
print('Retweets:',retweets.shape[0])
print('Originals:', df.shape[0] - retweets.shape[0])
# Out:
# Retweets: 2532
# Originals: 2982

# %% [markdown]
# There are more original tweets than retweets, but they are still similar in number. This could mean this topic or hashtag #enviroEd is not super popular. Althogh there is a decent amount of original tweeting, there does not seem to be much engagement and spread with the original tweets.

# %% [markdown]
# How often are there replies to tweets (showing interaction among people). Note that replies start with @username to show they are a reply to a specific user. Show a visualization.

# %%
replies_mask = []
for tweet in tweets_df['Tweet Text']:
    is_reply = tweet[0] == '@'
    replies_mask.append(is_reply)
replies = tweets_df[replies_mask]
replies.head()
# Out:
#          Screen Name                                         Tweet Text
# 17     @_mcisneros19  @doctormorrison Today at my nature journaling ...
# 94   @academe_atl_hs  @TorontoWaldorf Looking great! Ours is coming ...
# 159  @Alexis_Curious  @RangerRidley @KinderKids123 "permission" can ...
# 160  @Alexis_Curious  @RangerRidley so tech seen as more rigid and l...
# 164      @aliceleung  @ChrisVella2 I just realized you're moderator....

# %%
print('Replies:', replies.shape[0])
print('Non-replies:', df.shape[0] - replies.shape[0])
# Out:
# Replies: 590
# Non-replies: 4924

# %% [markdown]
# There are many more retweets and original tweets than reply tweets.

# %% [markdown]
# What are your observations about the distribution of followers counts (i.e., how many other users were following the poster of a given tweet)? Show a visualization.

# %%
fig = plt.figure(figsize=(15,8))
plt.xlabel('Number of Followers')
df['Followers'].plot(kind='hist', bins=100)
plt.show()

# %% [markdown]
# The number of followers for this data is right skewed. There are very few individuals with extremely high follower counts, while more than 5,000 users in this data have up to 8,000 followers (Number of upper limit / 100 bins gives the interval width of each rectangle). This lays ground for justification that there could be a lack of influential people in this data.

# %% [markdown]
# What are your observations about the distribution of follows counts (i.e., how many other accounts are followed by the poster of a given tweet) and how does it compare to the distribution of followers counts? Show a visualization.

# %%
fig = plt.figure(figsize=(15,8))
df['Follows'].plot(kind='hist', bins=100)
plt.show()

# %% [markdown]
# The number of follows for this data is a little more spread out between 0 to 10000 follows, however the data is still very much right-skewed. This could lay the foundation for determining how significant a person's follow is worth. A person may have many out-connections, but not many coming in. In this case, the less follows one may give, the more specialized they may be in the topic. There is an extreme focus for their accounts. This data shows that the majority of the people in this data do not have too many follows, and their's has potential for more specificity in the surrounding subject.

# %% [markdown]
# Where are people tweeting? We don’t have complete or easily parsed location data unfortunately. For a quick analysis, we can use the Location column, which is populated based on whatever a given user added in their profile on Twitter, although this may be blank or contain unhelpful information. Make two graphs showing the top 25 locations, one based on number of tweets sent from that location, and one based on number of users from that location.

# %%
loc_data = df['Location'].value_counts()[:25]
fig = plt.figure(figsize=(15,8))
loc_data.plot(kind='bar')
plt.show()
loc_data_w_unique_people = df.drop_duplicates('Screen Name', keep='last')['Location'].value_counts()[:25]
fig = plt.figure(figsize=(15,8))
loc_data_w_unique_people.plot(kind='bar')
plt.show()

# %% [markdown]
# When are people tweeting? Discuss your observations of when people tweet by analyzing the date column. Make a graph showing the number of tweets sent for each day of the week (Monday through Sunday). You may need to Google a bit for help with working with dates.

# %%
from datetime import date
data_array = df.values
days = []
for row in data_array:
    split = row[0].split('/')
    year = 0
    month = 0
    day = 0
    for i in range(len(split)):
        if i == 0:
            month = int(split[i])
        elif i == 1:
            day = int(split[i])
        else:
            year = int('20' + split[i])
        
    obj = date(year, month, day)    
    days.append(obj.strftime('%A'))
df_days = pd.DataFrame(days)
fig = plt.figure(figsize=(12,4))
df_days[0].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# What are people tweeting? Discuss your observations of the content of the tweets, based on the Tweet Text column. Make two graphs, one showing the top 50 most common words used in tweets, and one showing the top 20 most common topics (words starting with #).

# %%
data_array = df.values
word_list = []
for row in data_array:
    split = row[3].split(' ')
    for word in split:
        word_list.append(word)

# %%
# Most common words (stopwords included)
tweet_words = pd.DataFrame(word_list)
fig = plt.figure(figsize=(15,8))
tweet_words[0].value_counts()[:50].plot(kind='bar')
plt.show()

# %%
# most common topics
topic_list = []
for word in tweet_words[0]:
    if word.startswith('#'):
        topic_list.append(word)
topic_df = pd.DataFrame(topic_list)
fig = plt.figure(figsize=(12,8))
topic_df[0].value_counts()[:20].plot(kind='bar')
plt.xlabel('Topics')
plt.ylabel('Frequency of Mentionings')
plt.show()

# %% [markdown]
# ##### i. Who is tweeting?

# %% [markdown]
# i. Create a directed, weighted, social network graph where the nodes are the unique twitter users, the edges indicate if a user has mentioned another user in a tweet, and the weights are a count of how many times the user was mentioned. (Note that edges should be directed from the mentioning user to the mentioned user.) [The day 17 tutorial may be helpful here.]

# %%
G = nx.DiGraph()

# get unique twitter users, add to Graph obj
nodes = set(df['Screen Name'])
G.add_nodes_from(nodes)

# %%
edges = {}
t_array = df.values

for record in t_array:
    mentioner = record[1]
    indiv_words = record[3].split()
    mentioned = []
    for word in indiv_words:
        if word.startswith('@'):
            word = word.rstrip(string.punctuation)
            # There are some @ symbols that only have other punctuation attached, and end up as blank lines. Removing these from list
            # Ex: @..., I am unsure if the ... is continued in the whole Tweet Text column, or if it were trimmed to fit,
            # but these examples will be removed
            if len(word) > 0:
                mentioned.append(word)
    for person in mentioned:
        key = (mentioner, person)
        if key in edges:
            edges[key] += 1
        else:
            edges[key] = 1

# %%
# add edge to graph with determined weights
for (k, v) in edges.items():
    print(k ,':', v)
    G.add_edge(*k, weight=v)
# Out:
# ('@_Lightscap3s_', '@NatureBridge') : 2
# ('@_Lightscap3s_', '@5gyres') : 1
# ('@_Lindsay_Conway', '@savageducates') : 1
# ('@_mcisneros19', '@doctormorrison') : 1
# ('@_mcisneros19', '@sgilley12') : 1
# ('@_mcisneros19', '@DannyBavis') : 1
# ('@_mcisneros19', '@amk_elon') : 1
# ('@_mcisneros19', '@paigebl213') : 1
# ('@_swatik_', '@EnviroEducators') : 1
# ('@_swatik_', '@JackSmytheFC') : 1
# ('@_withah', '@ItsAboutTimeEDU') : 1
# ('@02Benson', '@GreeningForward') : 1
# ('@02Benson', '@COrgbon') : 1
# ('@109ThornKs', '@RangerRidley') : 1
# ('@1915Aurora', '@JasonSohigian') : 1
# ('@1915Aurora', '@ArmeniaTree') : 2
# ('@1915Aurora', '@CivilNetTV') : 1
# ('@1GratefulWorld', '@CNC90') : 1
# ('@1GratefulWorld', '@fatim_to') : 1
# ('@1GratefulWorld', '@MrsEimers') : 1
# ('@1GratefulWorld', '@OLVPrincipal') : 1
# ('@1stof7gens', '@GEOEC') : 1
# ('@1stof7gens', '@RachelNotley') : 1
# ('@1stof7gens', '@AlbertaEE') : 2
# ('@1stof7gens', '@cgeducation') : 1
# ('@1stof7gens', '@1stof7gens') : 1
# ('@2015_Project', '@ArmeniaTree') : 1
# ('@2015_Project', '@Asbarez') : 1
# ('@22C0in', '@EPA') : 1
# ('@2LisaMayer', '@EnviroEducators') : 7
# ('@2LisaMayer', '@FreeSeedsTO') : 1
# ('@2LisaMayer', '@actionbonnie') : 1
# ('@3PennyMovies', '@Sierra_BC') : 1
# ('@3wlittlefalls', '@MahaffyStars') : 1
# ('@3wlittlefalls', '@3wlittlefalls') : 1
# ('@3wlittlefalls', '@juliasilcox') : 1
# ('@500eco', '@EPA') : 1
# ('@5intadewi', '@EnviroEducators') : 1
# ('@5intadewi', '@CKEnvCentre') : 1
# ('@6Veronicadr', '@MHEducation') : 1
# ('@A_Dobbie11', '@KinderKids123') : 1
# ('@A_Dobbie11', '@RangerRidley') : 2
# ('@A_Dobbie11', '@PeelSchools') : 1
# ('@A_Dobbie11', '@GWFinlaysonFC') : 1
# ('@AACPS_PGD', '@MindShiftKQED') : 1
# ('@AACPS_PGD', '@TED_ED') : 1
# ('@AAPCA_States', '@EPA') : 2
# ('@AAPremlall', '@ZoeWeil') : 1
# ('@AAPremlall', '@HumaneEducation') : 1
# ('@AAPremlall', '@abchome') : 1
# ('@AAPremlall', '@BeyondOrganicD') : 1
# ('@AAPremlall', '@SustyQ') : 11
# ('@AAPremlall', '@RangerRidley') : 10
# ('@AAPremlall', '@stevenbody') : 1
# ('@AAPremlall', '@ChrisVella2') : 1
# ('@AAPremlall', '@Distractify') : 1
# ('@AAPremlall', '@greenBXmachine') : 1
# ('@AAPremlall', '@PeelSchools') : 1
# ('@AAPremlall', '@JackSmytheFC') : 1
# ('@AAPremlall', '@GWFinlaysonFC…') : 1
# ('@AAPremlall', '@PaulKelba') : 5
# ('@AAPremlall', '@AndrewkDoyle') : 1
# ('@AAPremlall', '@doctormorrison') : 1
# ('@AAPremlall', '@ycedillo94') : 1
# ('@aarniolinna', '@eerjournal') : 1
# ('@aarniolinna', '@PaulKelba') : 1
# ('@aarniolinna', '@GreenTeacherMag') : 1
# ('@aaronpaquette', '@Sierra_BC') : 1
# ('@aawasp', '@EPAregion2') : 1
# ('@AB_EP', '@AlbertaEE') : 1
# ('@AB_EP', '@1stof7gens') : 1
# ('@Abby_Retweet', '@UncleChaps') : 1
# ('@Abby_Retweet', '@jackehill') : 1
# ('@AbbyFDK', '@KinderFynes') : 1
# ('@ABEnvNet', '@GEOEC') : 1
# ('@ABEnvNet', '@MuseumofNature') : 1
# ('@ABEnvNet', '@AlbertaEE') : 1
# ('@ABEnvNet', '@ELC_Alberta') : 1
# ('@AbshireELC', '@CreativeSTAR') : 1
# ('@academe_atl_hs', '@TorontoWaldorf') : 1
# ('@ACGCNow', '@GEOEC') : 2
# ('@ACGCNow', '@MuseumofNature') : 1
# ('@ACGCNow', '@eecom_info') : 1
# ('@acostello715', '@RangerRidley') : 3
# ('@acostello715', '@GWFinlaysonFC') : 1
# ('@ACTcoachmodel', '@CreativeSTAR') : 1
# ('@adam_deyo', '@SusanKochVT') : 1
# ('@AdawDeng', '@CommunitiesONHS') : 1
# ('@AdawDeng', '@GrowingOshkosh') : 1
# ('@Adrian_T_Graham', '@KinderKids123') : 13
# ('@Adrian_T_Graham', '@RangerRidley') : 2
# ('@Adrian_T_Graham', '@PeelSchools') : 13
# ('@Adrian_T_Graham', '@Adrian_T_Graham') : 12
# ('@Adrian_T_Graham', '@SpringbrookPS') : 1
# ('@Adrian_T_Graham', '@DavidSuzukiSS') : 2
# ('@Adrian_T_Graham', '@peterlbursey') : 2
# ('@Adrian_T_Graham', '@vsilva_k') : 1
# ('@adriancamm', '@willjohnst') : 2
# ('@AdvanceTeaching', '@McGrawHillK12') : 1
# ('@AEWrightSchool', '@perfinker') : 1
# ('@afterschool4all', '@mellyball') : 4
# ('@afterschool4all', '@ScienceCenters') : 1
# ('@afterschool4all', '@MfentonFenton') : 4
# ('@afterschool4all', '@campSTEM') : 1
# ('@afterschool4all', '@OmahaZoo') : 1
# ('@afterschool4all', '@Girlstart') : 1
# ('@afterschool4all', '@RethinkSchools') : 1
# ('@afterschool4all', '@Click2Science') : 1
# ('@AfterschoolBudE', '@EPA') : 1
# ('@agileschools', '@jackehill') : 1
# ('@AgNews_Otto', '@AAPremlall') : 1
# ('@AHCeagles', '@PDSB_eco') : 1
# ('@AHCeagles', '@ON_EcoSchools') : 1
# ('@AHCeagles', '@HeartLake_SS') : 1
# ('@AHeathensDay', '@EPA') : 1
# ('@AIHA', '@EPA') : 1
# ('@aimunro', '@Pembina') : 1
# ('@aimunro', '@AlbertaEE') : 1
# ('@aimunro', '@GEF140') : 1
# ('@AIRNow', '@EPA') : 1
# ('@AJDownham', '@MindShiftKQED') : 1
# ('@AJDownham', '@KQEDLowdown') : 1
# ('@AJGRaalte', '@Moonbattery1') : 1
# ('@AJHartnett', '@Cowspiracy') : 1
# ('@AJHartnett', '@Truthdig') : 1
# ('@akgtCanada', '@RangerRidley') : 1
# ('@akperera', '@MHEducation') : 1
# ('@AlabamaDeptofEd', '@EDGreenRibbon') : 1
# ('@AlbertaEcotrust', '@AlbertaEE') : 1
# ('@AlbertaEcotrust', '@1stof7gens') : 1
# ('@AlbertaEcotrust', '@Pembina') : 1
# ('@AlbertaEE', '@1stof7gens') : 4
# ('@AlbertaEE', '@Pembina') : 2
# ('@AlbertaEE', '@AlbertaEcotrust') : 2
# ('@AlbertaEE', '@edmontonjournal') : 1
# ('@AlbertaEE', '@AlbertaTomorrow') : 1
# ('@AlbertaEE', '@GEOEC') : 2
# ('@AlbertaEE', '@insideeducation') : 1
# ('@AlbertaEE', '@enertweets') : 1
# ('@aleighzee', '@NatureBridge') : 1
# ('@aleighzee', '@outsidemagazine') : 1
# ('@Alexis_Curious', '@RangerRidley') : 4
# ('@Alexis_Curious', '@KinderKids123') : 1
# ('@alexleslieking', '@RLCParks') : 1
# ('@aliceleung', '@ChrisVella2') : 2
# ('@AliciaRaftery', '@UW') : 1
# ('@AliciaRaftery', '@climateinteract') : 1
# ('@AlisonSoligo', '@RangerRidley') : 1
# ('@AlistairWhitby', '@gehedges') : 2
# ('@AlistairWhitby', '@MidAtHike') : 1
# ('@AlistairWhitby', '@MAEOE_MD') : 3
# ('@AlistairWhitby', '@Good_Policies') : 3
# ('@AlistairWhitby', '@anacostiaws') : 1
# ('@AlistairWhitby', '@AlistairWhitby') : 1
# ('@AlistairWhitby', '@EnvLitCoor') : 1
# ('@AlistairWhitby', '@MAEO…') : 1
# ('@alkinahan', '@OCSBeco') : 1
# ('@alkinahan', '@ThomasMoreOCSB') : 1
# ('@alkinahan', '@ON_EcoSchools') : 1
# ('@allan_crawshaw', '@Sierra_BC') : 2
# ('@allsaykitsash', '@PlanktonPundit') : 1
# ('@almmog', '@PlanktonPundit') : 1
# ('@AlouOraelosi', '@PlanktonPundit') : 1
# ('@althourk', '@EPA') : 1
# ('@Am3liaGBall3w', '@AAPremlall') : 1
# ('@amandacyr4', '@RangerRidley') : 1
# ('@AmandaNicole487', '@EPA') : 2
# ('@AmberKraver', '@ItsAboutTimeEDU') : 1
# ('@Ambiente_MM', '@NAAEEStaff') : 2
# ('@AmericanForests', '@IslandWood') : 1
# ('@AmericanForests', '@GreeningDetroit') : 1
# ('@AmericanForests', '@AmericanForests') : 1
# ('@amk_elon', '@RangerRidley') : 7
# ('@amk_elon', '@CWF_FCF') : 11
# ('@amk_elon', '@amycoyote') : 2
# ('@amk_elon', '@doctormorrison') : 3
# ('@amk_elon', '@fowl_love') : 1
# ('@amk_elon', '@courtney_beavan') : 2
# ('@amk_elon', '@stevenbody') : 1
# ('@amk_elon', '@KinderFynes') : 1
# ('@amk_elon', '@PaulKelba') : 2
# ('@amk_elon', '@DannyBavis') : 1
# ('@amongstwits', '@ELKissner') : 1
# ('@AMuddyLife', '@RangerRidley') : 1
# ('@amusebook', '@MindShiftKQED') : 1
# ('@amusebook', '@TED_ED') : 1
# ('@amycoyote', '@doctormorrison') : 3
# ('@amycoyote', '@ClaireHWarden') : 1
# ('@amycoyote', '@CreativeSTAR') : 1
# ('@amycoyote', '@amycoyote') : 1
# ('@amycoyote', '@KinderKids123') : 4
# ('@amycoyote', '@CWF_FCF') : 6
# ('@amycoyote', '@Rylone3') : 1
# ('@amycoyote', '@SusanKochVT') : 1
# ('@amycoyote', '@amk_elon') : 4
# ('@amycoyote', '@facingthefuture') : 1
# ('@anacostiaws', '@AlistairWhitby') : 1
# ('@anacostiaws', '@anacostiaws') : 1
# ('@AnaLakhani', '@KinderFynes') : 1
# ('@andrewbieler', '@kathleenaikens') : 1
# ('@andrewnepean', '@OCSBeco') : 1
# ('@andrewnepean', '@andrewnepean') : 1
# ('@AngieClarksmama', '@vickiemorgado1') : 1
# ('@Angiesthinkin', '@RangerRidley') : 2
# ('@annabwild', '@BeWildON') : 1
# ('@annaisu', '@MHEducation') : 1
# ('@annasbelle', '@OCSBeco') : 1
# ('@annasbelle', '@ElizAnnSeton') : 1
# ('@annasbelle', '@ON_EcoSchools') : 1
# ('@AnnasClass', '@doctormorrison') : 1
# ('@AnnemarieHagan', '@visitpama') : 1
# ('@AnneMarieOB19', '@GanaraskaFC') : 1
# ('@AnneMarieOB19', '@DurhamCatholic') : 1
# ('@annie5133', '@EPA') : 1
# ('@AnnieCrawley', '@PatriciaNewman') : 1
# ('@ANPatterson317', '@McGrawHillK12') : 1
# ('@antiochseattle', '@gambassa') : 1
# ('@antiochseattle', '@IslandWood') : 1
# ('@antiochseattle', '@antiochseattle') : 1
# ('@antiochseattle', '@NAAEEStaff') : 1
# ('@AnushOConnor', '@JasonSohigian') : 1
# ('@AnushOConnor', '@ArmeniaTree') : 1
# ('@AnushOConnor', '@CivilNetTV') : 1
# ('@Apps4Ecology', '@Learn_OnTheFly') : 2
# ('@aprendetips', '@ItsAboutTimeEDU') : 1
# ('@AprilKelley07', '@AAPremlall') : 1
# ('@aquinn123', '@OfficialNGSS') : 1
# ('@Arbara0728B', '@NatureBridge') : 1
# ('@ArcandjMs', '@RangerRidley') : 3
# ('@Architecturhack', '@EZECNSW') : 1
# ('@ArizonaDEQ', '@EPA') : 1
# ('@arm_news', '@ArmeniaTree') : 1
# ('@ArmeniaTree', '@DavidMaxBraun') : 1
# ('@ArmeniaTree', '@enpifleg') : 1
# ('@ArmeniaTree', '@CivilNetTV') : 3
# ('@ArmeniaTree', '@Asbarez') : 1
# ('@ArmeniaTree', '@JasonSohigian') : 1
# ('@ArmeniaTree', '@ArmeniaTree') : 1
# ('@ArmstrongYYC', '@PaulKelba') : 1
# ('@artcollisions', '@PlanktonPundit') : 1
# ('@ArthurJChapman', '@BigHistoryPro') : 1
# ('@ArtPlaceAmerica', '@EPA') : 1
# ('@ascollins', '@calacademy') : 1
# ('@asforan', '@EnviroEducators') : 1
# ('@asforan', '@CKEnvCentre') : 1
# ('@asforan', '@RangerRidley') : 1
# ('@asforan', '@kristapetrie') : 1
# ('@asforan', '@KinderKids123') : 1
# ('@asforan', '@peterlbursey') : 1
# ('@asforan', '@MatthewOldridge') : 1
# ('@asforan', '@IslandWood') : 1
# ('@ASMEMilwaukee', '@STEMhero') : 1
# ('@ASRosentreter', '@CWF_FCF') : 1
# ('@ASRosentreter', '@participaction') : 1
# ('@AstronautThijs', '@jeffkirschner') : 1
# ('@AstronautThijs', '@litterati') : 1
# ('@ATHeritageArea', '@EPAregion2') : 1
# ('@AtifSherrif', '@EPA') : 1
# ('@ATS_Douglas', '@RangerRidley') : 1
# ('@AudreyGoz', '@EPA') : 1
# ('@aungmoeeco', '@EPAresearch') : 1
# ('@avivaloca', '@RangerRidley') : 1
# ('@aylward_tomas', '@CreativeSTAR') : 1
# ('@B7Anto', '@EPA') : 1
# ('@BacktoNatureNet', '@eecom_info') : 1
# ('@BacktoNatureNet', '@FlemingFrost') : 1
# ('@BacktoNatureNet', '@EnviroEducators') : 1
# ('@BacktoNatureNet', '@JackSmytheFC') : 1
# ('@badgerforest', '@CreativeSTAR') : 1
# ('@balmeras', '@NAAEEStaff') : 1
# ('@balmeras', '@IslandWood') : 1
# ('@bar_zie', '@RangerRidley') : 1
# ('@bar_zie', '@jackiegerstein') : 1
# ('@barbosa0415', '@vickiemorgado1') : 1
# ('@barbosa0415', '@MicrosoftEduCA') : 1
# ('@Barlutti', '@Sierra_BC') : 1
# ('@bashaierk', '@TLBoudell') : 2
# ('@bashaierk', '@bashaierk') : 1
# ('@BBPB_bali', '@SparkShiftLab') : 1
# ('@BBPB_bali', '@TEDTalks') : 1
# ('@BBPB_bali', '@BBPB_bali') : 1
# ('@bcaunter1', '@RangerRidley') : 1
# ('@BCCFarm', '@OurGreenChange') : 1
# ('@bcsanswers', '@LShenstone') : 1
# ('@BCspecies', '@Sierra_BC') : 1
# ('@beachcat11', '@jackiegerstein') : 1
# ('@beachcat11', '@RangerRidley') : 1
# ('@BEANOntario', '@EnviroEducators') : 1
# ('@BEANOntario', '@JackSmytheFC') : 1
# ('@BearTrust', '@savageducates') : 1
# ('@BearTrust', '@perfinker') : 1
# ('@BearTrust', '@BearTrust') : 1
# ('@BearTrust', '@ON_EcoSchools') : 1
# ('@BearTrust', '@EEPSA') : 1
# ('@BearTrust', '@NAAEEStaff') : 2
# ('@BearTrust', '@Sierra_BC') : 1
# ('@BearTrust', '@EPA') : 1
# ('@BearTrust', '@parks4all') : 1
# ('@BearTrust', '@MrSoclassroom') : 1
# ('@BearTrust', '@RangerRidley') : 1
# ('@beccakedenburg', '@IslandWood') : 1
# ('@BeckyBgomez3', '@McGrawHillK12') : 1
# ('@BeckyBgomez3', '@arborday') : 1
# ('@BEd_UOIT', '@EnviroEducators') : 1
# ('@BEd_UOIT', '@CKEnvCentre') : 1
# ('@BeebeHealthcare', '@EPA') : 1
# ('@BeeHouzz', '@AFolkHero') : 1
# ('@BeingExample', '@IslandWood') : 1
# ('@BelfountainGr2', '@BelfountainPS') : 1
# ('@BelfountainGr2', '@PeelSchools') : 1
# ('@BelfountainPS', '@deanneprins') : 1
# ('@BelfountainPS', '@belkinbrook') : 1
# ('@BelfountainPS', '@RangerRidley') : 1
# ('@BelfountainPS', '@BelfountainPS') : 2
# ('@BelfountainPS', '@BelfountainGr2') : 1
# ('@BelfountainPS', '@PeelSchools') : 1
# ('@BenDessen', '@EZECNSW') : 1
# ('@BenDessen', '@BenDessen') : 1
# ('@BenDessen', '@tarongazoo') : 1
# ('@BernardEcoTeam', '@PDSB_eco') : 1
# ('@BernardEcoTeam', '@EarthDayCanada') : 1
# ('@BernardEcoTeam', '@edutopia') : 1
# ('@Beth_Christie_', '@PaulKelba') : 1
# ('@Beth_Christie_', '@cblack') : 1
# ('@Beth_Christie_', '@Beth_Christie') : 1
# ('@bethanyvsmith', '@harrell_art') : 1
# ('@bethanyvsmith', '@ncartmuseum') : 1
# ('@BethEdwards423', '@PDSB_eco') : 1
# ('@BethEdwards423', '@EarthDayCanada') : 1
# ('@BethEdwards423', '@edutopia') : 1
# ('@bethlisser', '@RangerRidley') : 2
# ('@bettie_green', '@ELKissner') : 1
# ('@beverleybunker', '@EverActiveAB') : 1
# ('@BeWildON', '@cpaws') : 1
# ('@bgreen', '@realearthmama') : 1
# ('@bgreen', '@ChildrenNature') : 1
# ('@bgsulrnd', '@gaofei9') : 1
# ('@bgsulrnd', '@Kent_Darr') : 1
# ('@BhappiJJ', '@clclyne') : 1
# ('@BHSAACPS', '@EDGreenRibbon') : 1
# ('@BidgeeLandcare', '@EZECNSW') : 2
# ('@BidgeeLandcare', '@ChrisVella2') : 1
# ('@BidgeeLandcare', '@stevenbody') : 1
# ('@bidgeewidgee', '@vic72941') : 1
# ('@bidgeewidgee', '@vivianharris45') : 1
# ('@bidgeewidgee', '@stevenbody') : 1
# ('@bidgeewidgee', '@RangerRidley') : 1
# ('@bienenstock', '@CreativeSTAR') : 1
# ('@BillBrydon', '@bjacobsc') : 1
# ('@BillionOyster', '@Revkin') : 1
# ('@BillionOyster', '@dotearth') : 1
# ('@BillmillerBill', '@Sustainablehero') : 1
# ('@BillNigh', '@IslandWood') : 1
# ('@BinaIsrani', '@PlanktonPundit') : 1
# ('@Bio_Outreach', '@Smtp_Canada') : 1
# ('@BirdStudiesCan', '@Liza_Barney') : 1
# ('@BirdStudiesCan', '@GEDSB') : 1
# ('@bjacobsc', '@Sierra_BC') : 2
# ('@bjacobsc', '@outdoorKirsten') : 1
# ('@bjmcgough', '@participatelrn') : 1
# ('@BL_Modular', '@NAAEEStaff') : 1
# ('@BLM_CO', '@NaturesEd') : 1
# ('@BluebellBw', '@PlanktonPundit') : 2
# ('@bluechannel24', '@Sierra_BC') : 1
# ('@blujay4534', '@eerjournal') : 1
# ('@Bo_Kohen', '@jackiegerstein') : 1
# ('@boggs_e', '@IslandWood') : 1
# ('@BoltSecretSeeds', '@MallowEDIC') : 1
# ('@BoltSecretSeeds', '@corkcolibrary') : 1
# ('@book_diva', '@AAPremlall') : 1
# ('@BotSocSA', '@KirstenboschNBG') : 2
# ('@boxy_', '@EZECNSW') : 1
# ('@boxy_', '@ChrisVella2') : 1
# ('@boxy_', '@stevenbody') : 1
# ('@brad_crossman', '@ChrisVella2') : 1
# ('@brad_crossman', '@stevenbody') : 1
# ('@brad_crossman', '@BeyondBuggirl') : 1
# ('@brad_crossman', '@QuestaGame') : 1
# ('@brad_crossman', '@austmus') : 1
# ('@brad_crossman', '@museumvictoria') : 1
# ('@brad_crossman', '@philiproetman') : 1
# ('@brad_crossman', '@GrettaPecl') : 1
# ('@Brainpool_EU', '@AlistairWhitby') : 1
# ('@Brainpool_EU', '@gehedges') : 1
# ('@Brainpool_EU', '@MidAtHike') : 1
# ('@Brainpool_EU', '@MAEOE_MD') : 1
# ('@brasildeovelhas', '@PlanktonPundit') : 1
# ('@brendankference', '@EPA') : 1
# ('@BrewongleEEC', '@RangerRidley') : 18
# ('@BrewongleEEC', '@Joe_Teft') : 1
# ('@BrewongleEEC', '@BrewongleEEC') : 4
# ('@BrewongleEEC', '@ArcandjMs') : 1
# ('@BrewongleEEC', '@EZECNSW') : 7
# ('@BrewongleEEC', '@PeelSchools') : 1
# ('@BrewongleEEC', '@cya_outside') : 1
# ('@BrewongleEEC', '@ChrisVella2') : 8
# ('@BrewongleEEC', '@KinderFynes') : 2
# ('@BrewongleEEC', '@Chris…') : 1
# ('@BrewongleEEC', '@FSCaustralia') : 1
# ('@BrewongleEEC', '@stevenbody') : 1
# ('@BrewongleEEC', '@westernsydneyu') : 1
# ('@briandonovan', '@PlanktonPundit') : 1
# ('@brianne_yvonne', '@rfldn') : 2
# ('@BriarwoodLLC', '@KinderKids123') : 1
# ('@BriarwoodLLC', '@RangerRidley') : 1
# ('@BriarwoodLLC', '@PeelSchools') : 1
# ('@BriarwoodLLC', '@Adrian_T_Graham') : 1
# ('@BridalShuttle', '@RangerRidley') : 1
# ('@BridalShuttle', '@CWF_FCF') : 1
# ('@BrilRedJoanne', '@JodyAllair') : 1
# ('@brisdaleps', '@katlager') : 1
# ('@brisdaleps', '@brisdaleps') : 1
# ('@BrockBECE', '@RangerRidley') : 4
# ('@BrockBECE', '@EnviroEducators') : 1
# ('@BrockBECE', '@eduspeakers') : 1
# ('@BrockEducation', '@EnviroEducators') : 1
# ('@BrockEducation', '@JackSmytheFC') : 1
# ('@brookecarr80', '@EPA') : 1
# ('@BruceWard', '@IslandWood') : 1
# ('@BruceWard', '@UWCollegeOfEd') : 1
# ('@bruni_brunella', '@KnoxHartford') : 1
# ('@BryceRecsky', '@MindShiftKQED') : 1
# ('@BryceRecsky', '@TED_ED') : 1
# ('@BSC_BC', '@Liza_Barney') : 1
# ('@BSC_BC', '@VivianORC') : 1
# ('@BSC_BC', '@YRDSB') : 1
# ('@BSC_BC', '@BirdStudiesCan') : 1
# ('@BTCEA', '@EEPSA') : 1
# ('@BTCEA', '@bctf') : 1
# ('@BTG_KC', '@monarchwatch') : 1
# ('@bucknleaf', '@EnviroEducators') : 1
# ('@burntelmps', '@PDSB_eco') : 1
# ('@burntelmps', '@ON_EcoSchools') : 1
# ('@burntelmps', '@burntelmps') : 1
# ('@burntelmps', '@TourCNTower') : 1
# ('@burntelmps', '@Drake') : 1
# ('@burntelmps', '@PeelSchools') : 1
# ('@bwood___4', '@FocusOnForests') : 1
# ('@bwood___4', '@CanadianEcology') : 1
# ('@CaberTV', '@visitpama') : 1
# ('@cadman_john', '@cherandpete') : 1
# ('@cadolles', '@RangerRidley') : 1
# ('@CaGBC', '@CanadaGreenJobs') : 1
# ('@CaGBC', '@CaGBC') : 1
# ('@CAGreenRibbon', '@EPA') : 2
# ('@CAGreenRibbon', '@CEEIN4u') : 3
# ('@CAGreenRibbon', '@TheCACoast') : 1
# ('@CAGreenRibbon', '@projectwet') : 1
# ('@CAGreenRibbon', '@ucanr') : 1
# ('@CAGreenRibbon', '@PLT') : 1
# ('@CAGreenRibbon', '@CAStateParks') : 1
# ('@CAGreenRibbon', '@NAAEEStaff') : 2
# ('@CAGreenRibbon', '@EPAregion9') : 1
# ('@cali_toranzo', '@EPA') : 1
# ('@CalSpillWatch', '@CA_Pesticides') : 1
# ('@CambridgeEngZa', '@AlistairWhitby') : 1
# ('@cameroma', '@GEOEC') : 1
# ('@cameroma', '@cleanshorelines') : 1
# ('@cameroma', '@vanaqua') : 1
# ('@CampKawartha', '@EnviroEducators') : 2
# ('@CampKawartha', '@CKEnvCentre') : 2
# ('@CampKawartha', '@NaturesYear') : 1
# ('@CampKawartha', '@kawarthaNOW') : 1
# ('@CampKawartha', '@davidsuzukiqog') : 1
# ('@campSTEM', '@MfentonFenton') : 1
# ('@campSTEM', '@campSTEM') : 1
# ('@campSTEM', '@OmahaZoo') : 1
# ('@CanadaGreenJobs', '@CaGBC') : 1
# ('@CanadaGreenJobs', '@TBG_Canada') : 1
# ('@CanadaGreenJobs', '@BTCEA') : 1
# ('@CanadaGreenJobs', '@Sierra_BC') : 1
# ('@CanadaRenewable', '@Pembina') : 1
# ('@CanadaRenewable', '@AlbertaEE') : 1
# ('@CanadaRenewable', '@GEF140') : 1
# ('@CanadianFishn', '@CWF_FCF') : 1
# ('@CanGeoEdu', '@EnviroEducators') : 2
# ('@CanGeoEdu', '@CKEnvCentre') : 1
# ('@CanGeoEdu', '@JackSmytheFC') : 1
# ('@capn_madd_katt', '@ELKissner') : 1
# ('@CapobiaNB', '@AAPremlall') : 2
# ('@CaraClimpsonLee', '@BigHistoryPro') : 1
# ('@CarbonConvoCA', '@AlbertaEE') : 2
# ('@CarbonConvoCA', '@1stof7gens') : 1
# ('@CarbonConvoCA', '@Pembina') : 1
# ('@CarbonConvoCA', '@GEF140') : 1
# ('@carissahalton', '@GEOEC') : 1
# ('@carissahalton', '@RachelNotley') : 1
# ('@carissahalton', '@AlbertaEE') : 1
# ('@carissahalton', '@cgeducation') : 1
# ('@Caro42S', '@EPA') : 2
# ('@CarolBarash', '@MHEducation') : 1
# ('@caroljd1964', '@PlanktonPundit') : 1
# ('@carolspeers', '@RangerRidley') : 5
# ('@carolspeers', '@JackSmytheFC') : 2
# ('@carolspeers', '@PeelSchools') : 4
# ('@CarsonSieving', '@AAPremlall') : 1
# ('@cascience', '@JoeyElle') : 2
# ('@cascience', '@cascience') : 2
# ('@castleoaksps', '@RangerRidley') : 3
# ('@castleoaksps', '@CastleOaksPS') : 1
# ('@Catalina_Stout', '@KinderFynes') : 1
# ('@Catalina_Stout', '@PaulKelba') : 1
# ('@CatherineJudd1', '@EZECNSW') : 1
# ('@cblack__', '@PaulKelba') : 1
# ('@cblack__', '@cblack') : 1
# ('@cblack__', '@Beth_Christie') : 1
# ('@CDCasthma', '@NAAEEStaff') : 1
# ('@CDCEnvironment', '@EPAregion2') : 1
# ('@CDeeperlearning', '@ChrisVella2') : 1
# ('@CDeeperlearning', '@WestSydUFood_Ag') : 1
# ('@CDeeperlearning', '@EZECNSW') : 1
# ('@CdnOnlineSchool', '@CWF_FCF') : 1
# ('@CDolmont', '@CWF_FCF') : 1
# ('@CDolmont', '@stevenbody') : 1
# ('@CDolmont', '@GreenSchoolBali') : 1
# ('@CDolmont', '@ISPPCambodia') : 1
# ('@CEEIN4u', '@CA_Pesticides') : 1
# ('@CentennialSP', '@mossomcreek') : 1
# ('@CentennialSP', '@NoonsCreek') : 1
# ('@CentennialSP', '@ccmaltz') : 1
# ('@CentennialSrPS', '@PDSB_eco') : 1
# ('@CentennialSrPS', '@PeelSchools') : 1
# ('@cfectnews', '@EPA') : 1
# ('@CFrizelle', '@RangerRidley') : 1
# ('@cgeducation', '@GEOEC') : 1
# ('@cgeducation', '@RachelNotley') : 1
# ('@cgeducation', '@AlbertaEE') : 1
# ('@cgeducation', '@cgeducation') : 1
# ('@ChandaLCooper', '@SandhillREC') : 1
# ('@ChantalRegimbal', '@LShenstone') : 1
# ('@chaputski27', '@PDSB_eco') : 1
# ('@chaputski27', '@DPCDSBSchools') : 2
# ('@chaputski27', '@PeelSchools') : 1
# ('@chaputski27', '@regionofpeel') : 1
# ('@ChefDeannaNY', '@AAPremlall') : 1
# ('@CherineSpirou', '@EZECNSW') : 3
# ('@CherineSpirou', '@CherineSpirou') : 1
# ('@CherineSpirou', '@Skysie043') : 1
# ('@CherineSpirou', '@tevella71') : 1
# ('@CherineSpirou', '@ChrisVella2') : 1
# ('@CherineSpirou', '@steve_papp') : 2
# ('@CherineSpirou', '@FieldofMarsEEC') : 1
# ('@CherineSpirou', '@stevenbody') : 1
# ('@CherylSchnell', '@WisDPIenviroed') : 1
# ('@CherylZelmer', '@PaulKelba') : 2
# ('@CherylZelmer', '@HeatherMMcKay') : 1
# ('@ChescoChamber', '@StroudCenter') : 1
# ('@ChescoChamber', '@ChaddsFordLive') : 1
# ('@ChildrenNature', '@NAAEEStaff') : 1
# ('@ChildrenNature', '@CWF_FCF') : 2
# ('@ChildrenNature', '@ChildrenNature') : 1
# ('@ChildrenNature', '@mbingley') : 1
# ('@chocolat3b', '@MindShiftKQED') : 1
# ('@chocolat3b', '@TED_ED') : 1
# ('@chris_garces1', '@MindShiftKQED') : 1
# ('@chris_garces1', '@TED_ED') : 1
# ('@chrisobrienisok', '@BigHistoryPro') : 1
# ('@chrisrob1106', '@PDSB_eco') : 1
# ('@chrisrob1106', '@PeelSchools') : 1
# ('@chrisrob1106', '@ON_EcoSchools') : 1
# ('@ChristianLifeLd', '@rfldn') : 1
# ('@ChrisVella2', '@BrewongleEEC') : 18
# ('@ChrisVella2', '@WestSydUFood_Ag') : 3
# ('@ChrisVella2', '@RangerRidley') : 39
# ('@ChrisVella2', '@cya_outside') : 5
# ('@ChrisVella2', '@KinderFynes') : 2
# ('@ChrisVella2', '@ChrisVella2') : 27
# ('@ChrisVella2', '@EZECNSW') : 46
# ('@ChrisVella2', '@Chris…') : 1
# ('@ChrisVella2', '@vivianharris45') : 20
# ('@ChrisVella2', '@KateHelene') : 11
# ('@ChrisVella2', '@GibberagongEEC') : 2
# ('@ChrisVella2', '@DebHoggoz') : 12
# ('@ChrisVella2', '@LShenstone') : 12
# ('@ChrisVella2', '@MikeBartlettEdu') : 10
# ('@ChrisVella2', '@YES21stC') : 3
# ('@ChrisVella2', '@brandimoses2') : 1
# ('@ChrisVella2', '@ZeinaChalich') : 1
# ('@ChrisVella2', '@FieldofMarsEEC') : 6
# ('@ChrisVella2', '@BotanyBayEEC') : 1
# ('@ChrisVella2', '@GeorgesRiverEEC') : 1
# ('@ChrisVella2', '@bournda') : 1
# ('@ChrisVella2', '@LongneckLagoon') : 5
# ('@ChrisVella2', '@RNP_EEC') : 2
# ('@ChrisVella2', '@stevenbody') : 28
# ('@ChrisVella2', '@coolaustralia') : 5
# ('@ChrisVella2', '@tonialgray') : 1
# ('@ChrisVella2', '@EduTweetOz') : 1
# ('@ChrisVella2', '@aussieEDchat') : 2
# ('@ChrisVella2', '@fredgdomingo') : 1
# ('@ChrisVella2', '@steve_papp') : 6
# ('@ChrisVella2', '@westernsydneyu') : 1
# ('@ChrisVella2', '@CherineSpirou') : 4
# ('@ChrisVella2', '@aliceleung') : 6
# ('@ChrisVella2', '@LSF_LST') : 1
# ('@ChrisVella2', '@JulianCribb') : 1
# ('@ChrisVella2', '@tarongazoo') : 1
# ('@ChrisVella2', '@iBooks') : 1
# ('@ChrisVella2', '@BenNewsome') : 1
# ('@ChrisVella2', '@CentreWS') : 1
# ('@ChrisVella2', '@deb_clarke') : 1
# ('@ChrisVella2', '@NSWSPC') : 1
# ('@ChrisVella2', '@CatholicEdParra') : 1
# ('@ChrisVella2', '@NSWEducation') : 1
# ('@ChrisVella2', '@communityUOW') : 1
# ('@ChrisVella2', '@vic72941') : 4
# ('@ChrisVella2', '@nichall17') : 3
# ('@ChrisVella2', '@MRsalakas') : 1
# ('@ChrisVella2', '@EECCascade') : 1
# ('@ChrisVella2', '@JackSmytheFC') : 1
# ('@ChrisVella2', '@4DVirtualFarm') : 1
# ('@ChrisVella2', '@BeyondBuggirl') : 1
# ('@ChrisVella2', '@QuestaGame') : 1
# ('@ChrisVella2', '@austmus') : 1
# ('@ChrisVella2', '@museumvictoria') : 1
# ('@ChrisVella2', '@philiproetman') : 1
# ('@ChrisVella2', '@GrettaPecl') : 1
# ('@ChrisVella2', '@BowerBirdOrg') : 1
# ('@ChrisVella2', '@StreamwatchNSW') : 1
# ('@ChrisVella2', '@Condamine_nrm') : 1
# ('@ChrisVella2', '@AusLandcare') : 1
# ('@ChrisVella2', '@AMDigiVol') : 1
# ('@ChrisVella2', '@RedmapMarine') : 1
# ('@ChrisVella2', '@CitSciOZ') : 1
# ('@ChrisVella2', '@gaiaresources') : 1
# ('@ChrisVella2', '@piers_higgs') : 1
# ('@ChrisVella2', '@atlaslivingaust') : 1
# ('@ChrisVella2', '@KidTeachingKids') : 1
# ('@Chronicle5', '@eIncBoston') : 1
# ('@CineSeda', '@JasonSohigian') : 1
# ('@CineSeda', '@ArmeniaTree') : 1
# ('@CineSeda', '@CivilNetTV') : 1
# ('@CitizenCotto', '@inthebigmuddy') : 1
# ('@CitizenCotto', '@artisansasylum') : 1
# ('@CitSciOZ', '@ChrisVella2') : 1
# ('@CitSciOZ', '@stevenbody') : 1
# ('@CivilNetTV', '@JasonSohigian') : 1
# ('@CivilNetTV', '@ArmeniaTree') : 2
# ('@CivilNetTV', '@CivilNetTV') : 2
# ('@CKEnvCentre', '@EnviroEducators') : 2
# ('@CKEnvCentre', '@CKEnvCentre') : 2
# ('@CKEnvCentre', '@NaturesYear') : 1
# ('@CKEnvCentre', '@kawarthaNOW') : 1
# ('@CKEnvCentre', '@davidsuzukiqog') : 1
# ('@ckoos1', '@RangerRidley') : 1
# ('@clairewiththere', '@KinderKids123') : 1
# ('@clairewiththere', '@PeelSchools') : 1
# ('@clairewiththere', '@Adrian_T_Graham') : 1
# ('@ClaudiaIMacias', '@KinderKids123') : 1
# ('@claudioalpalice', '@EPA') : 1
# ('@clclyne', '@ugdsb') : 1
# ('@CleanAirMoms_IA', '@EPA') : 1
# ('@cleanshorelines', '@GEOEC') : 5
# ('@cleanshorelines', '@cleanshorelines') : 5
# ('@cleanshorelines', '@vanaqua') : 5
# ('@CliftIndustries', '@EPA') : 1
# ('@CliftonPS', '@MrsStajduhar1A') : 5
# ('@CliftonPS', '@CliftonPS') : 4
# ('@ClimateWise2015', '@EPA') : 2
# ('@ClimateWise2015', '@EPAresearch') : 1
# ('@ClintonBreau', '@jackiegerstein') : 1
# ('@cmkelleyteach', '@MindShiftKQED') : 1
# ('@cmkelleyteach', '@TED_ED') : 1
# ('@cmr3958', '@MindShiftKQED') : 1
# ('@cmr3958', '@TED_ED') : 1
# ('@cmresidents', '@RangerRidley') : 1
# ('@cmresidents', '@PeelSchools') : 1
# ('@CNC90', '@fatim_to') : 3
# ('@CNC90', '@MrsEimers') : 1
# ('@CNC90', '@OLVPrincipal') : 2
# ('@coad4kids', '@EPA') : 1
# ('@CoastalJCU', '@ChrisVella2') : 1
# ('@CoastalJCU', '@stevenbody') : 1
# ('@Cobra_Principal', '@MindShiftKQED') : 1
# ('@Cobra_Principal', '@TED_ED') : 1
# ('@CodyMillerPKY', '@pkyongedrs') : 1
# ('@COEOoutdoors', '@RangerRidley') : 1
# ('@ColbyCollege', '@HumanEcology') : 1
# ('@colchambers', '@KinderFynes') : 1
# ('@CommunitiesONHS', '@GrowingOshkosh') : 1
# ('@computerjen', '@CWF_FCF') : 1
# ('@ConnectedGarden', '@sshellery') : 1
# ('@ConnectedGarden', '@envirochelle') : 1
# ('@ConnectedGarden', '@STEMTeachTools') : 1
# ('@ConnectingTrue', '@Sierra_BC') : 1
# ('@connectinnature', '@IslandWood') : 1
# ('@contej', '@RangerRidley') : 3
# ('@contej', '@CWF_FCF') : 1
# ('@coolaustralia', '@EZECNSW') : 1
# ('@cooper4trustee', '@RangerRidley') : 2
# ('@cooper4trustee', '@PeelSchools') : 1
# ('@cordym', '@DavidSpencerEdu') : 1
# ('@CoreFav', '@AlistairWhitby') : 1
# ('@COrgbon', '@GreeningForward') : 1
# ('@COrgbon', '@COrgbon') : 1
# ('@corina_walker', '@stevenbody') : 1
# ('@corina_walker', '@ChrisVella2') : 1
# ('@corina_walker', '@LShenstone') : 1
# ('@corina_walker', '@vivianharris45') : 1
# ('@corina_walker', '@DebHoggoz') : 1
# ('@corina_walker', '@KateHelene') : 1
# ('@cosydirect', '@CreativeSTAR') : 1
# ('@CountrysidePDSB', '@RangerRidley') : 2
# ('@CountrysidePDSB', '@PeelSchools') : 1
# ('@CourseCreator', '@TAudubon') : 1
# ('@courtney_beavan', '@fowl_love') : 1
# ('@cpaws', '@BeWildON') : 1
# ('@cpaws', '@cpaws') : 1
# ('@CPIEcd', '@GRAINE_RA') : 1
# ('@CPSchoolCouncil', '@Smtp_Canada') : 1
# ('@CPSgarden', '@RangerRidley') : 5
# ('@CPTibbs', '@RangerRidley') : 1
# ('@CranstonSchool', '@PaulKelba') : 1
# ('@CrawshawAllan', '@Sierra_BC') : 1
# ('@CREATEenviro', '@GanaraskaFC') : 1
# ('@CREATEenviro', '@kprschools') : 1
# ('@CreativeSTAR', '@doctormorrison') : 1
# ('@CreativeSTAR', '@ClaireHWarden') : 1
# ('@CreativeSTAR', '@CreativeSTAR') : 1
# ('@CreativeSTAR', '@amycoyote') : 1
# ('@CristinaGardens', '@AAPremlall') : 1
# ('@Crozier_SI', '@Sustainablehero') : 1
# ('@CruisingKitty', '@PlanktonPundit') : 1
# ('@CUGeology', '@ItsAboutTimeEDU') : 1
# ('@CuriousDaffodil', '@RnfrstAlliance') : 1
# ('@CuriousDaffodil', '@PlumLandingPBS') : 1
# ('@CuriousDaffodil', '@NASA') : 1
# ('@CuriousDaffodil', '@rachelbconnolly') : 1
# ('@CuriousDaffodil', '@WGBH_edu') : 1
# ('@CurrenCougars', '@MoserMmoser') : 1
# ('@CurrenCougars', '@LatinoOutdoors') : 1
# ('@CurrenCougars', '@VeoverdeCL') : 1
# ('@CurrenCougars', '@USFWSPacSWest') : 1
# ('@cvr_synergy', '@EPA') : 1
# ('@CVWMA2', '@EPA') : 2
# ('@CWF_FCF', '@amk_elon') : 6
# ('@CWF_FCF', '@RangerRidley') : 13
# ('@CWF_FCF', '@KinderKids123') : 8
# ('@CWF_FCF', '@Rylone3') : 3
# ('@CWF_FCF', '@participaction') : 1
# ('@CWF_FCF', '@ilonadougherty') : 3
# ('@CWF_FCF', '@ForestSchoolCan') : 1
# ('@CWF_FCF', '@amycoyote') : 3
# ('@CWF_FCF', '@SusanKochVT') : 1
# ('@CWF_FCF', '@IUCN') : 1
# ('@CWF_FCF', '@doctormorrison') : 1
# ('@CWF_FCF', '@_mcisneros19') : 1
# ('@CWF_FCF', '@DannyBavis') : 1
# ('@CWF_FCF', '@sgilley12') : 1
# ('@CWF_FCF', '@paigebl213') : 1
# ('@CWF_FCF', '@CWF_FCF') : 5
# ('@CWF_FCF', '@AB_EP') : 1
# ('@CWF_FCF', '@GEOEC') : 2
# ('@CWF_FCF', '@HomeDepotCanada') : 1
# ('@CWF_FCF', '@ChildrenNature') : 1
# ('@cwppra', '@EPA') : 1
# ('@cya_outside', '@planthugger') : 1
# ('@cya_outside', '@RangerRidley') : 12
# ('@cya_outside', '@NaturlCuriosity') : 1
# ('@cya_outside', '@Brooklyn_North') : 1
# ('@cya_outside', '@WWFCanada') : 1
# ('@cya_outside', '@ChrisVella2') : 4
# ('@cya_outside', '@PaulKelba') : 1
# ('@cya_outside', '@Storify') : 1
# ('@cya_outside', '@RBGCanada') : 1
# ('@cya_outside', '@HamiltonNature') : 1
# ('@cya_outside', '@cya_outside') : 1
# ('@cya_outside', '@ArcandjMs') : 1
# ('@cya_outside', '@WestSydUFood_Ag') : 1
# ('@dancewithwonder', '@RangerRidley') : 2
# ('@dancewithwonder', '@EnviroEducators') : 1
# ('@Dandeliondirtrd', '@doctormorrison') : 1
# ('@Dandeliondirtrd', '@ShelburneFarms') : 1
# ('@daniel_ottmann', '@PlanktonPundit') : 1
# ('@DanielaGinta', '@Sierra_BC') : 2
# ('@DaniLStocks', '@EZECNSW') : 1
# ('@DannyBavis', '@doctormorrison') : 1
# ('@DannyBavis', '@PaulKelba') : 1
# ('@DasBridges', '@EPA') : 1
# ('@david_mcenaney', '@KeimJr') : 1
# ('@davidfprocter', '@Sierra_BC') : 1
# ('@Davidso8Darlene', '@NaturesYear') : 1
# ('@Davidso8Darlene', '@kawarthaNOW') : 1
# ('@Davidso8Darlene', '@davidsuzukiqog') : 1
# ('@DavidSpencerEdu', '@ugdsb') : 1
# ('@DavidSpencerEdu', '@conont') : 1
# ('@DavidSpencerEdu', '@OSEE') : 1
# ('@DavidSpencerEdu', '@EnviroEducators') : 7
# ('@DavidSpencerEdu', '@CKEnvCentre') : 2
# ('@DavidSpencerEdu', '@CanGeo') : 1
# ('@DavidSpencerEdu', '@RangerRidley') : 17
# ('@DavidSpencerEdu', '@AlbertaEE') : 1
# ('@DavidSpencerEdu', '@edmontonjournal') : 1
# ('@DavidSpencerEdu', '@1stof7gens') : 1
# ('@DavidSpencerEdu', '@Pembina') : 1
# ('@DavidSpencerEdu', '@Sierra_BC') : 1
# ('@DavidSpencerEdu', '@IslandWood') : 5
# ('@DavidSpencerEdu', '@UWCollegeOfEd') : 1
# ('@DavidSpencerEdu', '@EPA') : 2
# ('@DavidSpencerEdu', '@NaturlCuriosity') : 1
# ('@DavidSpencerEdu', '@participatelrn') : 2
# ('@DavidSpencerEdu', '@vickiemorgado1') : 1
# ('@DavidSpencerEdu', '@NAAEEStaff') : 4
# ('@DavidSpencerEdu', '@TLBoudell') : 1
# ('@DavidSpencerEdu', '@KinderKids123') : 5
# ('@DavidSpencerEdu', '@PDSB_eco') : 3
# ('@DavidSpencerEdu', '@PeelSchools') : 8
# ('@DavidSpencerEdu', '@Adrian_T_Graham') : 3
# ('@DavidSpencerEdu', '@ON_EcoSchools') : 1
# ('@DavidSpencerEdu', '@GEOEC') : 2
# ('@DavidSpencerEdu', '@cleanshorelines') : 1
# ('@DavidSpencerEdu', '@vanaqua') : 1
# ('@DavidSpencerEdu', '@CWF_FCF') : 1
# ('@DavidSpencerEdu', '@edutopia') : 1
# ('@DavidSpencerEdu', '@BacktoNatureNet') : 1
# ('@DavidSpencerEdu', '@FlemingFrost') : 1
# ('@DavidSpencerEdu', '@JackSmytheFC') : 2
# ('@DavidSpencerEdu', '@McGrawHillK12') : 1
# ('@DavidSpencerEdu', '@jackiegerstein') : 1
# ('@DavidSpencerEdu', '@ColbyCollege') : 1
# ('@DavidSpencerEdu', '@HumanEcology') : 1
# ('@DavidSpencerEdu', '@NatureBridge') : 1
# ('@DavidSpencerEdu', '@outsidemagazine') : 1
# ('@DavidSpencerEdu', '@AAPremlall') : 1
# ('@DavidSpencerEdu', '@bjacobsc') : 1
# ('@DavidSpencerEdu', '@LauraGilchrist4') : 1
# ('@DavidSpencerEdu', '@EZECNSW') : 4
# ('@DavidSpencerEdu', '@whiteoakspeel') : 1
# ('@DavidSpencerEdu', '@eecom_info') : 1
# ('@DavidSpencerEdu', '@fowl_love') : 1
# ('@DavidSpencerEdu', '@LShenstone') : 3
# ('@DavidSpencerEdu', '@stevenbody') : 5
# ('@DavidSpencerEdu', '@ChrisVella2') : 1
# ('@DavidSpencerEdu', '@vivianharris45') : 2
# ('@DavidSpencerEdu', '@DebHoggoz') : 1
# ('@DavidSpencerEdu', '@KateHelene') : 1
# ('@DavidSpencerEdu', '@CreativeSTAR') : 1
# ('@DavidSpencerEdu', '@seagreenED') : 1
# ('@DavidSpencerEdu', '@renomyclass') : 1
# ('@DavidSpencerEdu', '@peterlbursey') : 1
# ('@DavidSpencerEdu', '@BrewongleEEC') : 1
# ('@DavidSpencerEdu', '@DavidSpencerEdu') : 1
# ('@DavidSpencerEdu', '@bethlisser') : 1
# ('@DavidSuzukiSS', '@KinderKids123') : 6
# ('@DavidSuzukiSS', '@DavidSuzukiSS') : 5
# ('@DavidSuzukiSS', '@Mr_Crozier') : 1
# ('@DavidSuzukiSS', '@DSSSEcoAction') : 1
# ('@DavidSuzukiSS', '@leslie_edu') : 1
# ('@DavidSuzukiSS', '@DSSSguidance') : 1
# ('@DavidSuzukiSS', '@CWF_FCF') : 1
# ('@DavidSuzukiSS', '@RangerRidley') : 1
# ('@DavidSuzukiSS', '@PeelSchools') : 2
# ('@DavidSuzukiSS', '@PDSB_eco') : 1
# ('@DavidSuzukiSS', '@…') : 1
# ('@dawnbazely', '@gladyswlkong') : 1
# ('@dawnbazely', '@FocusOnForests') : 2
# ('@dawnbazely', '@JodyAllair') : 1
# ('@dbudlovsky', '@RangerRidley') : 1
# ('@dbudlovsky', '@NaturlCuriosity') : 1
# ('@DCOceanCentre', '@WMGLSI') : 1
# ('@DCOceanCentre', '@maisd') : 1
# ('@DCPSEco', '@RangerRidley') : 1
# ('@deanneprins', '@belkinbrook') : 1
# ('@deanneprins', '@RangerRidley') : 1
# ('@deanneprins', '@BelfountainPS') : 1
# ('@DeanShpprd', '@rfldn') : 1
# ('@DebHoggoz', '@ChrisVella2') : 12
# ('@DebHoggoz', '@EZECNSW') : 8
# ('@DebHoggoz', '@LShenstone') : 5
# ('@DebHoggoz', '@vivianharris45') : 3
# ('@DebHoggoz', '@KateHelene') : 1
# ('@DebHoggoz', '@FieldofMarsEEC') : 2
# ('@DebHoggoz', '@RangerRidley') : 2
# ('@DebHoggoz', '@steve_papp') : 1
# ('@DebHoggoz', '@stevenbody') : 3
# ('@DebiJules', '@DurhamCatholic') : 1
# ('@DebiJules', '@DurhamDSB') : 1
# ('@DebiJules', '@kprschools') : 1
# ('@DebiJules', '@ourkidsnet') : 1
# ('@DebiJules', '@EnviroEducators') : 2
# ('@DebiJules', '@JackSmytheFC') : 2
# ('@Deborah_Baer', '@KinderKids123') : 1
# ('@Deborah_Baer', '@RangerRidley') : 1
# ('@Deborah_Baer', '@KinderFynes') : 1
# ('@deeptimerocks', '@EPA') : 1
# ('@DeidreAusten', '@McGrawHillK12') : 1
# ('@DELawSchool', '@UMKCLaw') : 1
# ('@DellaLataille', '@KinderKids123') : 1
# ('@DellaLataille', '@PeelSchools') : 1
# ('@DellaLataille', '@Adrian_T_Graham') : 1
# ('@deni_nancy', '@RangerRidley') : 1
# ('@deni_nancy', '@HomeDepotCanada') : 1
# ('@deni_nancy', '@CWF_FCF') : 1
# ('@DenisonJudi', '@RangerRidley') : 1
# ('@DenisonJudi', '@PeelSchools') : 1
# ('@DeronBilous', '@GEOEC') : 1
# ('@DeronBilous', '@RachelNotley') : 1
# ('@DeronBilous', '@AlbertaEE') : 1
# ('@DeronBilous', '@cgeducation') : 1
# ('@DFLinton', '@RangerRidley') : 1
# ('@DFWM_MONTREAL', '@RangerRidley') : 1
# ('@DFWM_MONTREAL', '@CWF_FCF') : 1
# ('@DianeN56', '@PlanktonPundit') : 1
# ('@DibellinDiane', '@MHEducation') : 1
# ('@digitalcloudgal', '@eIncBoston') : 1
# ('@digitalcloudgal', '@burts…') : 1
# ('@digitalperiod', '@NAAEEStaff') : 1
# ('@director_fv', '@EPA') : 1
# ('@DiveNag', '@PlanktonPundit') : 1
# ('@DiversityInApps', '@OpenEbks') : 1
# ('@dkemball', '@EnviroEducators') : 3
# ('@dkemball', '@CKEnvCentre') : 2
# ('@dkemball', '@JackSmytheFC') : 1
# ('@DLitowski', '@KinderFynes') : 1
# ('@DMashak', '@selfgovwest') : 1
# ('@doccarpenter', '@doctormorrison') : 1
# ('@doctormorrison', '@ClaireHWarden') : 1
# ('@doctormorrison', '@CreativeSTAR') : 1
# ('@doctormorrison', '@amycoyote') : 2
# ('@doctormorrison', '@_mcisneros19') : 5
# ('@doctormorrison', '@amk_elon') : 7
# ('@doctormorrison', '@DannyBavis') : 6
# ('@doctormorrison', '@paigebl213') : 4
# ('@doctormorrison', '@sgilley12') : 5
# ('@doctormorrison', '@NBNC_VT') : 1
# ('@doctormorrison', '@AnnasClass') : 7
# ('@doctormorrison', '@elonuniversity') : 3
# ('@doctormorrison', '@HeadPhoenix') : 1
# ('@doctormorrison', '@facingthefuture') : 1
# ('@doctormorrison', '@ElizOCrawford') : 1
# ('@doctormorrison', '@Orion_Magazine') : 1
# ('@doctormorrison', '@RangerRidley') : 1
# ('@doctormorrison', '@PaulKelba') : 1
# ('@doctormorrison', '@courtney_beavan') : 1
# ('@doctormorrison', '@FarmBasedEd') : 1
# ('@doctormorrison', '@rockyrunfarm') : 1
# ('@doctormorrison', '@projectwet') : 1
# ('@doctormorrison', '@PLT') : 1
# ('@doctormorrison', '@eerjournal') : 1
# ('@DoggedWaterCo', '@envirojer') : 1
# ('@DoggedWaterCo', '@miOtt…') : 1
# ('@DoloresCascone', '@KinderFynes') : 1
# ('@DoloresCascone', '@RangerRidley') : 1
# ('@DoreenDunne', '@MrSoclassroom') : 1
# ('@DoreenDunne', '@RangerRidley') : 1
# ('@dori5', '@MoserMmoser') : 3
# ('@dori5', '@CurrenCougars') : 1
# ('@dovetailinc', '@FocusOnForests') : 1
# ('@dowhatulove247', '@EPA') : 1
# ('@DP_Dietrich', '@EPA') : 1
# ('@DPaulsonSTEM', '@EDGreenRibbon') : 1
# ('@DPdiscovery', '@TDFEF') : 1
# ('@DPdiscovery', '@OntScienceCtr') : 1
# ('@Dr_chrishair', '@willjohnst') : 1
# ('@dr_riina', '@participatelrn') : 1
# ('@DRBC1961', '@EPA') : 1
# ('@DrBGillette', '@GISEd') : 1
# ('@DrBGillette', '@KCLibrary') : 2
# ('@DrBGillette', '@PowellGardens') : 1
# ('@DrBGillette', '@andrea_wulf') : 1
# ('@DreamRiderHQ', '@rangerridley') : 1
# ('@DreamRiderHQ', '@PaulKelba') : 3
# ('@DreamRiderHQ', '@RangerRidley') : 2
# ('@DreamRiderHQ', '@HWDSB') : 1
# ('@DreamRiderHQ', '@HWCDSB') : 1
# ('@DreamRiderHQ', '@epsb') : 1
# ('@DREandVICKI', '@IslandWood') : 1
# ('@DREandVICKI', '@GreeningDetroit') : 1
# ('@DREandVICKI', '@AmericanForests') : 1
# ('@drfr4n', '@MindShiftKQED') : 1
# ('@drfr4n', '@KQEDLowdown') : 1
# ('@DrMazzula', '@NLM_SIS') : 1
# ('@DrMazzula', '@EPA') : 1
# ('@DrQuesada', '@EPA') : 1
# ('@DrTillieHarris', '@femaregion2') : 1
# ('@DrTillieHarris', '@EPAregion2') : 1
# ('@DSSSEcoAction', '@leslie_edu') : 1
# ('@DSSSEcoAction', '@DSSSguidance') : 1
# ('@DSSSEcoAction', '@KinderKids123') : 3
# ('@DSSSEcoAction', '@DavidSuzukiSS') : 3
# ('@DSSSEcoAction', '@PeelSchools') : 1
# ('@DSSSEcoAction', '@…') : 1
# ('@dtangred', '@LorraineTv1884') : 1
# ('@dtangred', '@TVDSB') : 1
# ('@dtangred', '@erinmutch') : 1
# ('@duncwhite', '@ndhalls') : 1
# ('@duncwhite', '@RobinsonBev') : 1
# ('@duncwhite', '@ArmstrongYYC') : 1
# ('@duncwhite', '@PaulKelba') : 1
# ('@DurhamCatholic', '@GanaraskaFC') : 1
# ('@DurhamCatholic', '@DurhamCatholic') : 1
# ('@e_malyk', '@KinderKids123') : 1
# ('@e_malyk', '@RangerRidley') : 1
# ('@eamorrowesq', '@McGrawHillK12') : 1
# ('@EANumeracy', '@CreativeSTAR') : 1
# ('@earth2holly', '@EPA') : 1
# ('@Earthducation', '@BrewongleEEC') : 2
# ('@earthforce', '@McGrawHillK12') : 1
# ('@earthforce', '@arborday') : 1
# ('@earthforce', '@vincemeldrum') : 1
# ('@earthforce', '@earthforce') : 1
# ('@EarthVitalSigns', '@EPA') : 1
# ('@EastWestLit', '@PatriciaNewman') : 1
# ('@ece_fs', '@Jackiecoryell') : 1
# ('@ece_fs', '@razoo') : 1
# ('@echo_nature', '@MindaBerbeco') : 1
# ('@echo_nature', '@AlexZwissler') : 2
# ('@echo_nature', '@climateone') : 2
# ('@echo_nature', '@BillNye') : 1
# ('@echo_nature', '@OfficialNGSS') : 1
# ('@echo_nature', '@LiveScience') : 1
# ('@eco_partners', '@EPA') : 1
# ('@EcoCentres', '@RangerRidley') : 1
# ('@EcoCentres', '@EcoCentres') : 1
# ('@ecoclub_ffm', '@scorvese') : 1
# ('@ecoclub_ffm', '@FFMcGinnCES') : 1
# ('@ecoclub_ffm', '@myRichmondHill') : 1
# ('@ecoclub_ffm', '@ecoclub_ffm') : 1
# ('@ecoclub_ffm', '@ON_EcoSchools') : 1
# ('@ecodigitography', '@EZECNSW') : 1
# ('@ecodigitography', '@BenDessen') : 1
# ('@ecodigitography', '@tarongazoo') : 1
# ('@EcoFriendlySask', '@SEPNetwork') : 1
# ('@ecorise', '@educationweek') : 1
# ('@EcoSchools', '@TrumacarPrimary') : 1
# ('@EcoSchoolsTDSB', '@EnviroEducators') : 1
# ('@EcoSchoolsTDSB', '@CKEnvCentre') : 1
# ('@EcoSchoolsTDSB', '@RangerRidley') : 1
# ('@EcoSchoolsTDSB', '@EcoSchoolsTDSB') : 1
# ('@EcoSchoolsTDSB', '@PDSB_eco…') : 1
# ('@EcosourceGreen', '@lynes_christine') : 1
# ('@ecyspokane', '@IslandWood') : 1
# ('@Ed_Tmprince', '@CreativeSTAR') : 1
# ('@EdCamp905', '@RangerRidley') : 2
# ('@EdCamp905', '@yrdsbtalk') : 1
# ('@edcampGSU', '@LHuffling') : 1
# ('@edcampGSU', '@NSTA') : 1
# ('@eden_janna', '@Mr_Marshall') : 1
# ('@EdenwoodMS', '@RangerRidley') : 1
# ('@EdenwoodMS', '@PeelSchools') : 1
# ('@EdGameTec', '@savageducates') : 1
# ('@EdGameTec', '@Sierra_BC') : 1
# ('@EdGameTec', '@AccentInns') : 1
# ('@EdGameTec', '@jackiegerstein') : 1
# ('@EdGameTec', '@sustain_a_b0wl') : 1
# ('@EdGameTec', '@PaulKelba') : 2
# ('@EdGameTec', '@cblack') : 1
# ('@EdGameTec', '@Beth_Christie') : 1
# ('@EDGreenRibbon', '@NAAEEStaff') : 7
# ('@EDGreenRibbon', '@NASA') : 1
# ('@EDGreenRibbon', '@EECapacity') : 1
# ('@EDGreenRibbon', '@CREC_TwoRivers') : 1
# ('@EDGreenRibbon', '@EducateCT') : 1
# ('@EdmScience', '@EnviroEducators') : 1
# ('@EdmScience', '@GEOEC') : 5
# ('@EdmScience', '@cleanshorelines') : 2
# ('@EdmScience', '@vanaqua') : 2
# ('@EdmScience', '@MuseumofNature') : 1
# ('@EdmScience', '@eecom_info') : 1
# ('@EdmScience', '@CWF_FCF') : 1
# ('@EdSpeakersCo', '@RangerRidley') : 5
# ('@EdSpeakersCo', '@CWF_FCF') : 1
# ('@edtechsynergy', '@MindShiftKQED') : 1
# ('@edtechsynergy', '@KQEDLowdown') : 1
# ('@EdTechTill', '@McGrawHillK12') : 1
# ('@educationarena', '@eerjournal') : 4
# ('@edutopia', '@rangerridley') : 1
# ('@EEASC1', '@RSWCD') : 1
# ('@EEASC1', '@EEASC1') : 1
# ('@EEASC1', '@CongareeNPS') : 1
# ('@EEPSA', '@perfinker') : 1
# ('@EEPSA', '@EEPSA') : 1
# ('@EEPSA', '@LSF') : 1
# ('@eerjournal', '@eerjournal') : 1
# ('@eerjournal', '@doctormorrison') : 1
# ('@ehardenScience', '@OfficialNGSS') : 1
# ('@EHordyskiLuong', '@PaulKelba') : 1
# ('@eIncBoston', '@burtsbees') : 2
# ('@eIncBoston', '@RenewBoston') : 1
# ('@eIncBoston', '@GreenovateBos') : 1
# ('@eIncBoston', '@netimpact') : 1
# ('@eIncBoston', '@museumofscience') : 1
# ('@eIncBoston', "@NatGeo's") : 1
# ('@EIRCorg', '@EDGreenRibbon') : 1
# ('@ejabel2', '@selfgovwest') : 1
# ('@ElaineE1ho', '@GreenLearning') : 1
# ('@ElaineE1ho', '@ODIdev') : 1
# ('@elemenous', '@MsYorksClass') : 1
# ('@elemenous', '@litterati') : 1
# ('@EliaMSLibraryLC', '@JFVandermeij') : 1
# ('@ElisaLitvin', '@BigHistoryPro') : 1
# ('@ElizabethBastos', '@RangerRidley') : 1
# ('@ElizabethNeves6', '@KinderKids123') : 3
# ('@ElizabethNeves6', '@vsilva_k') : 1
# ('@ElizabethNeves6', '@PeelSchools') : 1
# ('@ElizabethNeves6', '@peterlbursey') : 1
# ('@ElizAnnSeton', '@OCSBeco') : 1
# ('@ElizAnnSeton', '@ElizAnnSeton') : 1
# ('@ElizAnnSeton', '@ON_EcoSchools') : 1
# ('@ELKissner', '@RangerRidley') : 1
# ('@ELKissner', '@ycedillo94') : 1
# ('@ELKissner', '@exploreorg') : 1
# ('@emahoneywest', '@IslandWood') : 1
# ('@emahoneywest', '@UWCollegeOfEd') : 1
# ('@EmbarrassingPET', '@PatriciaNewman') : 1
# ('@EMillerFCPSAA', '@MindShiftKQED') : 1
# ('@EMillerFCPSAA', '@TED_ED') : 1
# ('@EmmanuelQ', '@MsYorksClass') : 1
# ('@EmmanuelQ', '@litterati') : 1
# ('@emmoretti', '@MrsMorgado1') : 1
# ('@emmoretti', '@StTimsEcoTeam') : 1
# ('@emmoretti', '@StTimothyDPCDSB') : 1
# ('@emmoretti', '@LPapaloni') : 1
# ('@Energy_Lit', '@PDSB_eco') : 1
# ('@enerscore', '@EPA') : 1
# ('@EnertechB', '@EPAresearch') : 1
# ('@enertweets', '@AlbertaEE') : 1
# ('@enertweets', '@AlbertaEcotrust') : 1
# ('@enertweets', '@AlbertaTomorrow') : 1
# ('@enertweets', '@GEOEC') : 1
# ('@enertweets', '@insideeducation') : 1
# ('@enertweets', '@enertweets') : 1
# ('@enickers', '@StuartCDSchool') : 1
# ('@enickers', '@PhillyBugMuseum') : 1
# ('@envir490', '@pie_saster') : 1
# ('@envirochap_d', '@Sierra_BC') : 1
# ('@envirochelle', '@sshellery') : 1
# ('@envirochelle', '@envirochelle') : 1
# ('@envirochelle', '@STEMTeachTools') : 1
# ('@EnviroEducators', '@CKEnvCentre') : 5
# ('@EnviroEducators', '@RangerRidley') : 6
# ('@EnviroEducators', '@EarthDayCanada') : 1
# ('@EnviroEducators', '@EnviroEducators') : 7
# ('@EnviroEducators', '@LSF_LST') : 1
# ('@EnviroEducators', '@DavidSuzukiFDN') : 3
# ('@EnviroEducators', '@ON_EcoSchools') : 1
# ('@EnviroEducators', '@NWF') : 1
# ('@EnviroEducators', '@SustyQ') : 1
# ('@EnviroEducators', '@DrScottSampson') : 1
# ('@EnviroEducators', '@RichLouv') : 1
# ('@EnviroEducators', '@actionbonnie') : 1
# ('@EnviroEducators', '@2LisaMayer') : 3
# ('@EnviroEducators', '@FreeSeedsTO') : 1
# ('@EnviroEducators', '@JackSmytheFC') : 10
# ('@EnviroEducators', '@environmentont') : 1
# ('@EnviroEducators', '@PaulKelba') : 1
# ('@EnviroEducators', '@guardia…') : 1
# ('@envirojer', '@envirojer') : 3
# ('@envirojer', '@RangerRidley') : 5
# ('@envirojer', '@googlemaps') : 3
# ('@envirojer', '@ELKissner') : 1
# ('@envirojer', '@PaulKelba') : 2
# ('@envirojer', '@KinderKids123') : 2
# ('@envirojer', '@miOttawa') : 1
# ('@envirojer', '@KinderFynes') : 1
# ('@envirojer', '@Learn_OnTheFly') : 2
# ('@envirojer', '@YouTube') : 1
# ('@envirojer', '@TheBurdenFilm') : 1
# ('@envirojer', '@Vimeo') : 1
# ('@envirojer', '@TeachAgPSU') : 1
# ('@envirojer', '@FosterDanielD') : 1
# ('@EnvirologicTech', '@EPAresearch') : 1
# ('@EnvironEdofIL', '@NAAEEStaff') : 1
# ('@environmentaide', '@Sierra_BC') : 1
# ('@EnvironmentYork', '@EnviroEducators') : 1
# ('@EnvironmentYork', '@JackSmytheFC') : 1
# ('@EPAclimatectr', '@EPA') : 3
# ('@EPAgreenbldg', '@EPA') : 1
# ('@EPAland', '@EPA') : 1
# ('@EPAnewengland', '@EPA') : 3
# ('@EPAregion2', '@EPA') : 4
# ('@EPAregion2', '@EPAresearch') : 2
# ('@EPAregion3', '@EPAregion2') : 2
# ('@EPAregion3', '@EPA') : 2
# ('@EPAregion3', '@EPAresearch') : 1
# ('@EPAregion7', '@EPA') : 7
# ('@EPAresearch', '@EPA') : 2
# ('@EPAresearch', '@EPAregion2') : 1
# ('@EPN_SouthBayLA', '@EPA') : 1
# ('@EricHarvieSchl', '@MamaJoules') : 1
# ('@EricHarvieSchl', '@globeandmail') : 1
# ('@EricHarvieSchl', '@fowl_love') : 1
# ('@EricHarvieSchl', '@PaulKelba') : 3
# ('@EricHarvieSchl', '@Kinde…') : 1
# ('@EricHarvieSchl', '@stevenbody') : 1
# ('@EricHarvieSchl', '@doctormorrison') : 1
# ('@EricHarvieSchl', '@courtney_beavan') : 1
# ('@EricHarvieSchl', '@RangerRidley') : 1
# ('@EricHarvieSchl', '@cblack') : 1
# ('@EricHarvieSchl', '@Beth_Christie') : 1
# ('@EricHarvieSchl', '@HeatherMMcKay') : 1
# ('@Erik20234', '@vivianharris45') : 1
# ('@Erin_YYC', '@lbingley') : 1
# ('@ErinDealey', '@PatriciaNewman') : 1
# ('@erinmutch', '@RangerRidley') : 1
# ('@erinmutch', '@CreativeSTAR') : 1
# ('@ErinSperling', '@FoodshareTO') : 1
# ('@esargent184', '@PlanktonPundit') : 1
# ('@ESGenviroclub', '@EnviroEducators') : 1
# ('@ESGenviroclub', '@RangerRidley') : 1
# ('@EthiopiaOnline', '@envirojer') : 1
# ('@EvaApelqvist', '@McGrawHillK12') : 1
# ('@EvaApelqvist', '@arborday') : 1
# ('@Evo_Explorer', '@LHuffling') : 1
# ('@Evo_Explorer', '@NSTA') : 1
# ('@Ew331Melissa', '@OCSBeco') : 1
# ('@Ew331Melissa', '@ThomasMoreOCSB') : 1
# ('@Ew331Melissa', '@ON_EcoSchools') : 1
# ('@ExploLive', '@RangerRidley') : 1
# ('@ExpTotalHealth', '@EPA') : 1
# ('@eye4msu', '@envirojer') : 1
# ('@Ezab1', '@KinderKids123') : 2
# ('@Ezab1', '@PeelSchools') : 2
# ('@Ezab1', '@Adrian_T_Graham') : 2
# ('@EZECNSW', '@BenDessen') : 1
# ('@EZECNSW', '@tarongazoo') : 1
# ('@EZECNSW', '@RangerRidley') : 22
# ('@EZECNSW', '@ChrisVella2') : 21
# ('@EZECNSW', '@vivianharris45') : 20
# ('@EZECNSW', '@LShenstone') : 15
# ('@EZECNSW', '@MikeBartlettEdu') : 3
# ('@EZECNSW', '@BeachTeachFun') : 1
# ('@EZECNSW', '@KateHelene') : 10
# ('@EZECNSW', '@8pm') : 1
# ('@EZECNSW', '@vic72941') : 1
# ('@EZECNSW', '@CurryQuaily') : 1
# ('@EZECNSW', '@MackenzieTamlin') : 1
# ('@EZECNSW', '@ChristinaMcGhe') : 1
# ('@EZECNSW', '@JAnnSheridan') : 1
# ('@EZECNSW', '@nichall17') : 1
# ('@EZECNSW', '@tevella71') : 2
# ('@EZECNSW', '@mattmckenzie333') : 1
# ('@EZECNSW', '@GreenTeacherOz') : 1
# ('@EZECNSW', '@CatherineJudd1') : 1
# ('@EZECNSW', '@KerryAtTaronga') : 1
# ('@EZECNSW', '@NSWEducation') : 1
# ('@EZECNSW', '@CaddeyMark') : 1
# ('@EZECNSW', '@tonialgray') : 1
# ('@EZECNSW', '@GayeBraiding') : 1
# ('@EZECNSW', '@corina_walker') : 1
# ('@EZECNSW', '@FieldofMarsEEC') : 4
# ('@EZECNSW', '@DebHoggoz') : 6
# ('@EZECNSW', '@hollowsashomes') : 1
# ('@EZECNSW', '@BirdlifeOz') : 1
# ('@EZECNSW', '@Earthwatch_Aus') : 1
# ('@EZECNSW', '@BrewongleEEC') : 7
# ('@EZECNSW', '@WestSydUFood_Ag') : 2
# ('@EZECNSW', '@brandimoses2') : 1
# ('@EZECNSW', '@EZECNSW') : 5
# ('@EZECNSW', '@EnviroStories') : 1
# ('@EZECNSW', '@stevenbody') : 8
# ('@EZECNSW', '@CherineSpirou') : 3
# ('@EZECNSW', '@Skysie043') : 1
# ('@EZECNSW', '@steve_papp') : 3
# ('@EZECNSW', '@aliceleung') : 4
# ('@EZECNSW', '@LSF_LST') : 1
# ('@EZECNSW', '@coolaustralia') : 3
# ('@EZECNSW', '@GibberagongEEC') : 1
# ('@EZECNSW', '@RNP_EEC') : 1
# ('@EZECNSW', '@doctormorrison') : 1
# ('@EZECNSW', '@BotanyBayEEC') : 1
# ('@EZECNSW', '@LongneckLagoon') : 1
# ('@FairMountain', '@ELKissner') : 2
# ('@FaithCommonGood', '@AlbertaEE') : 1
# ('@FaithCommonGood', '@edmontonjournal') : 1
# ('@FaithCommonGood', '@1stof7gens') : 1
# ('@FaithCommonGood', '@Pembina') : 1
# ('@FalakSaleem159', '@EPAresearch') : 1
# ('@FalconridgeCBE', '@duncwhite') : 1
# ('@FalconridgeCBE', '@ndhalls') : 1
# ('@FalconridgeCBE', '@RobinsonBev') : 1
# ('@FalconridgeCBE', '@ArmstrongYYC') : 1
# ('@FalconridgeCBE', '@PaulKelba') : 1
# ('@FarrahFazia', '@RangerRidley') : 1
# ('@FarrahFazia', '@CastleOaksPS') : 1
# ('@fatim_to', '@RangerRidley') : 13
# ('@fatim_to', '@EPA') : 1
# ('@fatim_to', '@laura_warburton') : 1
# ('@fatim_to', '@cnc90') : 1
# ('@fatim_to', '@tonifalcioni') : 1
# ('@fatim_to', '@msvdevine') : 1
# ('@fatim_to', '@CWF_FCF') : 1
# ('@fatim_to', '@Rylone3') : 1
# ('@fatim_to', '@CNC90') : 3
# ('@fatim_to', '@fatim_to') : 3
# ('@fatim_to', '@OLVPrincipal') : 4
# ('@fatim_to', '@MrsEimers') : 2
# ('@fatim_to', '@EnviroEducators') : 1
# ('@fayzaprebtani', '@JFVandermeij') : 1
# ('@FDKlorenville', '@RangerRidley') : 1
# ('@femaregion2', '@EPAregion2') : 1
# ('@FFMcGinnCES', '@scorvese') : 1
# ('@FFMcGinnCES', '@FFMcGinnCES') : 1
# ('@FFMcGinnCES', '@myRichmondHill') : 1
# ('@FFMcGinnCES', '@ecoclub_ffm') : 1
# ('@FFMcGinnCES', '@ON_EcoSchools') : 1
# ('@FieldofMarsEEC', '@stevenbody') : 4
# ('@FieldofMarsEEC', '@ChrisVella2') : 3
# ('@FieldofMarsEEC', '@EZECNSW') : 3
# ('@FieldofMarsEEC', '@steve_papp') : 1
# ('@FieldofMarsEEC', '@iTunesU') : 1
# ('@FieldofMarsEEC', '@iBooks') : 1
# ('@FieldsAECG', '@BrewongleEEC') : 1
# ('@findog99', '@MindShiftKQED') : 1
# ('@findog99', '@TED_ED') : 1
# ('@fionammorrison', '@CreativeSTAR') : 1
# ('@firstgreatwater', '@StroudCenter') : 2
# ('@firstgreatwater', '@ChaddsFordLive') : 1
# ('@fishingprofs', '@EPA') : 1
# ('@FocusOnForests', '@EnviroEducators') : 1
# ...
# ('@SudOuestMtl9', '@CWF_FCF') : 1
# ('@SueEckel', '@RangerRidley') : 1
# ('@SueEckel', '@CastleOaksPS') : 1
# ('@suefried', '@RangerRidley') : 3
# ('@suefried', '@DavidSuzukiFDN') : 1
# ('@SueLawton2010', '@RangerRidley') : 2
# ('@SueLawton2010', '@GWFinlaysonFC') : 1
# ('@SueLawton2010', '@JackSmytheFC') : 2
# ('@SueLawton2010', '@PDSBBritanniaSH') : 1
# ('@SueLawton2010', '@PDSB_eco') : 1
# ('@SueLawton2010', '@PeelSchools') : 1
# ('@SueLawton2010', '@whiteoakspeel') : 1
# ('@SueOvertonAP', '@KinderKids123') : 1
# ('@SueOvertonAP', '@PeelSchools') : 1
# ('@SunBrilliance', '@Sustainablehero') : 1
# ('@sunfloweroville', '@kzelmer') : 1
# ('@Supermanskye', '@CWF_FCF') : 1
# ('@surishaikh', '@KinderKids123') : 1
# ('@surishaikh', '@PeelSchools') : 1
# ('@susanwright1031', '@usfs_nrs') : 1
# ('@Sustainable613', '@CanadaGreenJobs') : 1
# ('@SustyQ', '@RangerRidley') : 10
# ('@SustyQ', '@AAPremlall') : 8
# ('@SustyQ', '@BeyondOrganicD') : 1
# ('@SustyQ', '@stevenbody') : 1
# ('@SustyQ', '@ChrisVella2') : 1
# ('@SustyQ', '@Distractify') : 1
# ('@SustyQ', '@PaulKelba') : 6
# ('@SustyQ', '@AndrewkDoyle') : 1
# ('@SustyQ', '@SustyQ') : 4
# ('@SustyQ', '@doctormorrison') : 1
# ('@SustyQ', '@ycedillo94') : 1
# ('@SuzanneAxelsson', '@RangerRidley') : 1
# ('@SuzanneAxelsson', '@KinderFynes') : 1
# ('@SuzanneDunbar5', '@CreativeSTAR') : 1
# ('@swahl', '@FocusOnForests') : 1
# ('@SwanLakeOE', '@EnviroEducators') : 1
# ('@SwanLakeOE', '@CKEnvCentre') : 1
# ('@SwanLakeOE', '@RangerRidley') : 1
# ('@SwanLakeOE', '@PaulKelba') : 1
# ('@SwanLakeOE', '@SEPNetwork') : 1
# ('@taBrielleGab3p', '@Revkin') : 1
# ('@taBrielleGab3p', '@dotearth') : 1
# ('@TacomaTalks', '@TAudubon') : 1
# ('@tammysross1', '@MindShiftKQED') : 1
# ('@tammysross1', '@TED_ED') : 1
# ('@tanya_l_p', '@FocusOnForests') : 2
# ('@tanya_l_p', '@CanadianEcology') : 1
# ('@taradayorzecho', '@PDSB_eco') : 1
# ('@taradayorzecho', '@PeelSchools') : 1
# ('@TashaRoa', '@wimpcom') : 1
# ('@TAudubon', '@PuyallupWater') : 1
# ('@tcdixon3', '@GEOEC') : 33
# ('@tcdixon3', '@RachelNotley') : 3
# ('@tcdixon3', '@AlbertaEE') : 3
# ('@tcdixon3', '@cgeducation') : 3
# ('@tcdixon3', '@earthhour') : 6
# ('@tcdixon3', '@cleanshorelines') : 2
# ('@tcdixon3', '@vanaqua') : 2
# ('@tcdixon3', '@MuseumofNature') : 3
# ('@tcdixon3', '@eecom_info') : 9
# ('@tcdixon3', '@CWF_FCF') : 2
# ('@tcdixon3', '@NatureCentre') : 3
# ('@tcdixon3', '@CityofRedDeer') : 1
# ('@tcdixon3', '@albertateachers') : 1
# ('@tcdixon3', '@KathyWorobec') : 1
# ('@tcdixon3', '@cityofcalgary') : 1
# ('@TDSB_mendoza', '@RangerRidley') : 4
# ('@TDSB_mendoza', '@MrHuynh9') : 1
# ('@TDSB_STEM', '@EnviroEducators') : 1
# ('@TDSB_STEM', '@JackSmytheFC') : 1
# ('@TeachOwl', '@PDSB_eco') : 1
# ('@TeachOwl', '@ON_EcoSchools') : 1
# ('@TeachOwl', '@PeelSchools') : 1
# ('@Teachwith_Hart', '@PDSB_eco') : 5
# ('@Teachwith_Hart', '@PeelSchools') : 3
# ('@Teachwith_Hart', '@ON_EcoSchools') : 2
# ('@Teachwith_Hart', '@regionofpeel') : 1
# ('@techdde', '@RangerRidley') : 1
# ('@techdde', '@PeelSchools') : 1
# ('@TechDiscountsMN', '@EnvInitiative') : 1
# ('@TechieAng', '@RangerRidley') : 1
# ('@TedGroschScifi', '@eIncBoston') : 1
# ('@TedGroschScifi', '@UncleChaps') : 1
# ('@telesange', '@BearTrust') : 1
# ('@temarabrown', '@BeWildON') : 1
# ('@temarabrown', '@cpaws') : 1
# ('@TenStrands', '@IslandWood') : 1
# ('@TenStrands', '@RangerRidley') : 2
# ('@terryamerson', '@AAPremlall') : 1
# ('@tevella71', '@EZECNSW') : 1
# ('@tevella71', '@CherineSpirou') : 1
# ('@tevella71', '@Skysie043') : 1
# ('@tevella71', '@tevella71') : 1
# ('@TexasSpaceGrant', '@EPA') : 3
# ('@the_connectory', '@MindShiftKQED') : 1
# ('@the_connectory', '@KQEDLowdown') : 1
# ('@TheBurdenFilm', '@envirojer') : 1
# ('@TheBurdenFilm', '@TheBurdenFilm') : 1
# ('@TheBurdenFilm', '@Vimeo') : 1
# ('@TheEarthNetwork', '@DavidSpencerEdu') : 2
# ('@thegatewaybug', '@EPA') : 1
# ('@TheGentYYC', '@AlbertaEE') : 1
# ('@TheGentYYC', '@1stof7gens') : 1
# ('@TheGentYYC', '@Pembina') : 1
# ('@TheodoraNaso', '@EPAresearch') : 1
# ('@TheOneHeLuvs', '@EPA') : 1
# ('@TheRealEmmaRose', '@IslandWood') : 1
# ('@TheRealEmmaRose', '@UWCollegeOfEd') : 1
# ('@TheWild_Goose', '@CreativeSTAR') : 1
# ('@TheWire_Ebooks', '@MarylandMunros') : 1
# ('@thewonders80', '@HeatherMMcKay') : 1
# ('@thewonders80', '@PaulKelba') : 1
# ('@ThinkEarthEd', '@RenewBoston') : 1
# ('@ThinkEarthEd', '@EPA') : 1
# ('@ThinkEarthEd', '@MrsStajduhar1A') : 1
# ('@ThinkEarthEd', '@CliftonPS') : 1
# ('@ThinkinEd', '@KinderFynes') : 1
# ('@ThinkinEd', '@RangerRidley') : 1
# ('@ThinkinEd', '@PeelSchools') : 1
# ('@ThomasMoreOCSB', '@OCSBeco') : 2
# ('@ThomasMoreOCSB', '@ThomasMoreOCSB') : 2
# ('@ThomasMoreOCSB', '@ON_EcoSchools') : 1
# ('@ThornLodgePS', '@HameedEd') : 1
# ('@ThornLodgePS', '@ThornLodgePS') : 1
# ('@ThornLodgePS', '@RangerRidley') : 1
# ('@ThornLodgePS', '@EnviroEducators') : 1
# ('@Tim_W_Patterson', '@AlbertaEE') : 1
# ('@Tim_W_Patterson', '@1stof7gens') : 1
# ('@tina_zita', '@RangerRidley') : 8
# ('@tina_zita', "@RangerRidley's") : 1
# ('@tina_zita', '@EnviroEducators') : 1
# ('@tina_zita', '@JackSmytheFC') : 1
# ('@tina_zita', '@KinderKids123') : 1
# ('@tina_zita', '@PeelSchools') : 1
# ('@tina_zita', '@the_mulc') : 1
# ('@tina_zita', '@TeacherHann') : 1
# ('@tinhlavu', '@mellyball') : 1
# ('@tinhlavu', '@RethinkSchools') : 1
# ('@TLBoudell', '@RangerRidley') : 4
# ('@TLBoudell', '@Learn_OnTheFly') : 3
# ('@TLBoudell', '@bashaierk') : 1
# ('@TLBoudell', '@BigHistoryPro') : 1
# ('@TLBoudell', '@NASA_Wallops') : 1
# ('@TLBoudell', '@NatureMattersVa') : 1
# ('@TLBoudell', '@ChildrenNature') : 1
# ('@TLBoudell', '@EPA') : 1
# ('@TLBoudell', '@PaulKelba') : 1
# ('@TLBoudell', '@CWF_FCF') : 3
# ('@TLBoudell', '@Storify') : 1
# ('@TLBoudell', '@Apps4Ecology') : 1
# ('@TocoJuju', '@Learn_OnTheFly') : 1
# ('@TocoJuju', '@VirginiaDCR') : 1
# ('@TodayAtSch00L', '@RangerRidley') : 1
# ('@toffler_sarah', '@CWF_FCF') : 1
# ('@tomkenroadms', '@PDSB_eco') : 1
# ('@tomkenroadms', '@tomkenroadms') : 1
# ('@tomkenroadms', '@PeelSchools') : 1
# ('@tommasolana', '@PaulKelba') : 1
# ('@tommasolana', '@tommasolana') : 1
# ('@ToniFalcion', '@MrsEimers') : 1
# ('@ToniFalcion', '@OLVPrincipal') : 1
# ('@ToniFalcion', '@fatim_to') : 1
# ('@ToniFalcion', '@CNC90') : 1
# ('@tonydec3112', '@PlanktonPundit') : 1
# ('@tooba_shakeel', '@EnviroEducators') : 1
# ('@Tools73', '@EZECNSW') : 1
# ('@TracyEdmunds', '@ThinkEarthEd') : 2
# ('@TracyEdmunds', '@RenewBoston') : 1
# ('@TRCA_Edu', '@PDSB_eco') : 1
# ('@TRCA_Edu', '@ON_EcoSchools') : 1
# ('@TRCA_Edu', '@regionofpeel') : 1
# ('@TRCA_Edu', '@PEYAlliance') : 1
# ('@TRCA_Edu', '@TRCA_Edu') : 1
# ('@TRCA_Edu', '@PeelSchools') : 1
# ('@trembathkindie', '@CreativeSTAR') : 1
# ('@TrentUSoE', '@EnviroEducators') : 1
# ('@TrillmaticRT', '@eerjournal') : 1
# ('@Trish_ll', '@RangerRidley') : 1
# ('@Trish_ll', '@EnviroEducators') : 2
# ('@TruDavidJackson', '@RangerRidley') : 1
# ('@TSMScouncil', '@EnviroEducators') : 1
# ('@TSMScouncil', '@CKEnvCentre') : 1
# ('@TTHDragons', '@EPA') : 1
# ('@TurnerCreekES', '@NorthCarolinaEE') : 1
# ('@TurnerCreekES', '@NCReserve') : 1
# ('@TurnerCreekES', '@TurnerCreekES') : 1
# ('@TurnerCreekES', '@WCPSS') : 1
# ('@twitturriculum', '@BigHistoryPro') : 1
# ('@txbutterfly380', '@EPA') : 1
# ('@UCDSB', '@EnviroEducators') : 1
# ('@UCDSB', '@CKEnvCentre') : 1
# ('@UF_IFAS', '@Pinellas_Ext_NR') : 1
# ('@UF_IFAS', '@UF_IFAS') : 1
# ('@UF_IFAS', '@CHNEP') : 1
# ('@UMKCLaw', '@DELawSchool') : 1
# ('@UMKCLaw', '@UMKCLaw') : 1
# ('@unarose7', '@RangerRidley') : 1
# ('@unarose7', '@CWF_FCF') : 1
# ('@Unitingschools', '@willjohnst') : 1
# ('@UOITGoGreen', '@EnviroEducators') : 1
# ('@UOITGoGreen', '@CKEnvCentre') : 1
# ('@UOITsummercamps', '@EnviroEducators') : 5
# ('@UOITsummercamps', '@CKEnvCentre') : 2
# ('@urban_sci', '@NaturesYear') : 1
# ('@urban_sci', '@kawarthaNOW') : 1
# ('@urban_sci', '@davidsuzukiqog') : 1
# ('@urbanclimate', '@NAAEEStaff') : 2
# ('@USCCanada', '@EnviroEducators') : 1
# ('@usfsdnf', '@usfs_nrs') : 1
# ('@USFSRockyMtns', '@usfs_nrs') : 1
# ('@USGBC_GA', '@EPA') : 1
# ('@USGBCNJ', '@EPA') : 1
# ('@USGS_Virginia', '@lavabombs') : 1
# ('@UTOC_club', '@CanadaGreenJobs') : 1
# ('@uttjess', '@ecopedagogue') : 1
# ('@UVtreatsAIS', '@DavidSpencerEdu') : 1
# ('@UVtreatsAIS', '@InvSp') : 1
# ('@UWCollegeOfEd', '@IslandWood') : 1
# ('@UWCollegeOfEd', '@UWCollegeOfEd') : 1
# ('@UWCollegeOfEd', '@usedgov') : 1
# ('@UWCollegeOfEd', '@suzieboss') : 1
# ('@uwpoe', '@IslandWood') : 1
# ('@uwpoe', '@SMUCareerCenter') : 1
# ('@uwpoe', '@MobilizeGreen') : 1
# ('@VacaRecycling', '@EPA') : 1
# ('@ValValedwards14', '@RangerRidley') : 1
# ('@ValValedwards14', '@PeelSchools') : 1
# ('@VanHJab', '@ArmeniaTree') : 2
# ('@VanHJab', '@Asbarez') : 1
# ('@VanRod1', '@BigHistoryPro') : 1
# ('@vansopinion8ted', '@Sierra_BC') : 1
# ('@VaughanRetweets', '@TorontoWaldorf') : 1
# ('@Venkataramanaia', '@EPA') : 1
# ('@verenanz', '@SparkShiftLab') : 1
# ('@verenanz', '@TEDTalks') : 1
# ('@verenanz', '@BBPB_bali') : 1
# ('@vic72941', '@EZECNSW') : 2
# ('@vic72941', '@vivianharris45') : 3
# ('@vic72941', '@stevenbody') : 4
# ('@vic72941', '@ChrisVella2') : 4
# ('@vic72941', '@LShenstone') : 2
# ('@vic72941', '@DebHoggoz') : 2
# ('@vic72941', '@KateHelene') : 1
# ('@vic72941', '@LongneckLagoon') : 3
# ('@vic72941', '@RangerRidley') : 1
# ('@vickiemorgado1', '@MicrosoftEduCA') : 1
# ('@vickipage1332', '@laur_stoot') : 1
# ('@VigilesGroup', '@MindShiftKQED') : 1
# ('@VigilesGroup', '@TED_ED') : 1
# ('@VillageCoal', '@Sierra_BC') : 1
# ('@vincemeldrum', '@earthforce') : 1
# ('@VirginiaDCR', '@TheNatGen') : 1
# ('@VisitBraggCreek', '@GEOEC') : 1
# ('@VisualPersist', '@Learn_OnTheFly') : 1
# ('@VisualPersist', '@VirginiaDCR') : 1
# ('@VisualPersist', '@envirojer') : 1
# ('@VisualPersist', '@miOtt…') : 1
# ('@VisualPersist', '@bjacobsc') : 1
# ('@VisualPersist', '@EnviroEducators') : 3
# ('@vivian_wood', '@BigHistoryPro') : 1
# ('@vivianharris45', '@DebHoggoz') : 5
# ('@vivianharris45', '@ChrisVella2') : 8
# ('@vivianharris45', '@BrewongleEEC') : 1
# ('@vivianharris45', '@stevenbody') : 12
# ('@vivianharris45', '@EZECNSW') : 3
# ('@vivianharris45', '@CherineSpirou') : 1
# ('@vivianharris45', '@LShenstone') : 1
# ('@vivianharris45', '@vivianharris45') : 2
# ('@vivianharris45', '@KateHelene') : 1
# ('@vivianharris45', '@RangerRidley') : 7
# ('@vivianharris45', '@MikeBartlettEdu') : 1
# ('@vivianharris45', '@vic72941') : 2
# ('@vivianharris45', '@LongneckLagoon') : 1
# ('@vivianharris45', '@EECCascade') : 1
# ('@VivianORC', '@Liza_Barney') : 1
# ('@VivianORC', '@VivianORC') : 1
# ('@VivianORC', '@YRDSB') : 1
# ('@VivianORC', '@BirdStudiesCan') : 1
# ('@VnP_Topsoil', '@rfldn') : 2
# ('@VocesAnalisa', '@EPA') : 1
# ('@vp_slee', '@RangerRidley') : 1
# ('@vp_slee', '@PeelSchools') : 1
# ('@VPKThomas', '@RangerRidley') : 4
# ('@VPKThomas', '@PeelSchools') : 3
# ('@VPLoiLam', '@PDSB_eco') : 1
# ('@VPLoiLam', '@regionofpeel') : 1
# ('@vrydberg', '@GEOEC') : 1
# ('@vsilva_k', '@KinderKids123') : 2
# ('@vsilva_k', '@vsilva_k') : 2
# ('@vsilva_k', '@PeelSchools') : 2
# ('@vsilva_k', '@peterlbursey') : 2
# ('@vtprincipals', '@VTrecycles') : 1
# ('@vtprincipals', '@VTEducation') : 1
# ('@vtprincipals', '@vtprincipals') : 1
# ('@vtprincipals', '@VTED_SafeSchool') : 1
# ('@VTrecycles', '@VTEducation') : 1
# ('@VTrecycles', '@vtprincipals') : 1
# ('@VTrecycles', '@VTED_SafeSchool') : 1
# ('@WaldorfSWLondon', '@TorontoWaldorf') : 1
# ('@ward_mills23', '@MindShiftKQED') : 1
# ('@ward_mills23', '@TED_ED') : 1
# ('@WarwickEY', '@CreativeSTAR') : 1
# ('@WatsEd', '@KinderKids123') : 1
# ('@WatsEd', '@RangerRidley') : 1
# ('@WatsEd', '@PeelSchools') : 1
# ('@WccampbellWendy', '@stevenbody') : 1
# ('@WccampbellWendy', '@doctormorrison') : 1
# ('@WccampbellWendy', '@courtney_beavan') : 1
# ('@WCEEStaff', '@NAAEEStaff') : 1
# ('@WCEEStaff', '@UW') : 1
# ('@WCEEStaff', '@MountRainierNPS') : 1
# ('@WeAreTheFace1', '@EPA') : 1
# ('@webbersed', '@METSchoolPanama') : 1
# ('@webbhalpern', '@EPAregion2') : 1
# ('@WelcomePtbo', '@NaturesYear') : 1
# ('@WelcomePtbo', '@kawarthaNOW') : 1
# ('@WelcomePtbo', '@davidsuzukiqog') : 1
# ('@Wendy_Dowling', '@KinderFynes') : 1
# ('@Wendy_Dowling', '@RangerRidley') : 1
# ('@WenzelAlex', '@IslandWood') : 1
# ('@westernulibsEDU', '@CJSMTE') : 1
# ('@WestSydUFood_Ag', '@RangerRidley') : 2
# ('@WestSydUFood_Ag', '@cya_outside') : 1
# ('@WestSydUFood_Ag', '@ArcandjMs') : 1
# ('@WestSydUFood_Ag', '@WestSydUFood_Ag') : 2
# ('@WestSydUFood_Ag', '@EZECNSW') : 5
# ('@WestSydUFood_Ag', '@BrewongleEEC') : 2
# ('@WestSydUFood_Ag', '@ChrisVella2') : 9
# ('@WestSydUFood_Ag', '@tonialgray') : 2
# ('@WestSydUFood_Ag', '@RCE_GWS') : 2
# ('@WestSydUFood_Ag', '@sustaineduau') : 2
# ('@WestSydUFood_Ag', '@FAotC') : 2
# ('@WestSydUFood_Ag', '@RAS_NSW') : 2
# ('@WestSydUFood_Ag', '@SariesMc') : 1
# ('@WestSydUFood_Ag', '@Skysie043') : 1
# ('@WestSydUFood_Ag', '@kurraleigh') : 1
# ('@WestSydUFood_Ag', '@AgVisionAus') : 1
# ('@WestSydUFood_Ag', '@JoYohana') : 1
# ('@WestSydUFood_Ag', '@stevenbody') : 9
# ('@WestSydUFood_Ag', '@BelindaCay') : 1
# ('@WestSydUFood_Ag', '@coolaustralia') : 1
# ('@WestSydUFood_Ag', '@vivianharris45') : 2
# ('@WestSydUFood_Ag', '@MikeBartlettEdu') : 2
# ('@WestSydUFood_Ag', '@nichall17') : 2
# ('@WestwoodGI', '@AlbertaEE') : 6
# ('@WestwoodGI', '@edmontonjournal') : 1
# ('@WestwoodGI', '@1stof7gens') : 3
# ('@WestwoodGI', '@Pembina') : 2
# ('@WestwoodGI', '@AlbertaEcotrust') : 1
# ('@WestwoodGI', '@AlbertaTomorrow') : 1
# ('@WestwoodGI', '@GEOEC') : 2
# ('@WestwoodGI', '@insideeducation') : 1
# ('@WestwoodGI', '@enertweets') : 1
# ('@WetWednesdays_', '@RangerRidley') : 1
# ('@WickedDecent', '@MrsMurat') : 1
# ('@WidowDNA', '@FocusOnForests') : 1
# ('@WidowDNA', '@CanadianEcology') : 1
# ('@WildHomesLondon', '@RangerRidley') : 1
# ('@WildLearning1', '@DavidSpencerEdu') : 1
# ('@WildLearning1', '@conont') : 1
# ('@WilkyEcoTeam', '@EnviroEducators') : 1
# ('@WilkyEcoTeam', '@CKEnvCentre') : 1
# ('@williamsden_', '@RangerRidley') : 1
# ('@winecountrydog', '@CA_Pesticides') : 1
# ('@winevalleygirl', '@pwpreserve') : 1
# ('@winevalleygirl', '@ENewsJournal') : 1
# ('@WisDPIenviroed', '@STEMhero') : 1
# ('@WisDPIenviroed', '@WCSS1') : 1
# ('@WisDPIenviroed', '@WisDPIsocstu') : 1
# ('@withoutmary', '@BeWildON') : 1
# ('@withoutmary', '@cpaws') : 1
# ('@WM_Books', '@PlanktonPundit') : 1
# ('@wonderstaples', '@RangerRidley') : 9
# ('@wonderstaples', '@KinderFynes') : 4
# ('@wonderstaples', '@ELKissner') : 1
# ('@wonderstaples', '@peterlbursey') : 2
# ('@wonderstaples', '@wonderstaples') : 1
# ('@wonderstaples', '@KinderKids123') : 2
# ('@wonderstaples', '@PeelSchools') : 1
# ('@wonderstaples', '@EnviroEducators') : 1
# ('@wonderstaples', '@HomeDepotCanada') : 1
# ('@wonderstaples', '@CWF_FCF') : 1
# ('@Woodstockbs10', '@CreativeSTAR') : 1
# ('@World_of_K', '@CWF_FCF') : 1
# ('@World_of_K', '@HomeDepot') : 1
# ('@World_of_K', '@EK_Kinders') : 1
# ('@WPeelsb', '@KinderFynes') : 1
# ('@wpokorny', '@KinderKids123') : 1
# ('@wpokorny', '@RangerRidley') : 1
# ('@wrenasmir', '@steve_papp') : 1
# ('@wshsecology', '@bcsanswers') : 1
# ('@wywemubaluza', '@jackehill') : 1
# ('@XFazio_BrockU', '@EnviroEducators') : 1
# ('@XFazio_BrockU', '@JackSmytheFC') : 1
# ('@Xnonsense0', '@EPA') : 1
# ('@YAM2200', '@EPA') : 1
# ('@yannist2edu', '@RangerRidley') : 1
# ('@yawnSwanson', '@UncleChaps') : 1
# ('@ycedillo94', '@RangerRidley') : 1
# ('@YEKA_Envi_Solu', '@EPA') : 1
# ('@YES21stC', '@BrewongleEEC') : 2
# ('@YES21stC', '@MikeBartlettEdu') : 1
# ('@YES21stC', '@YES21stC') : 1
# ('@YES21stC', '@ChrisVella2') : 1
# ('@YES21stC', '@stevenbody') : 1
# ('@YES21stC', '@EZECNSW') : 1
# ('@YES21stC', '@vivianharris45') : 1
# ('@ymahdessian', '@ArmeniaTree') : 1
# ('@YorkUScientists', '@gladyswlkong') : 1
# ('@YorkUScientists', '@FocusOnForests') : 2
# ('@YosemiteNPS', '@NatureBridge') : 1
# ('@youthdotgov', '@EPA') : 5
# ('@youthwavemakers', '@PaulKelba') : 1
# ('@youthwavemakers', '@youthwavemakers') : 1
# ('@youthwavemakers', '@GetToKnowPrgm') : 1
# ('@YRDSBEcoSchools', '@EnviroEducators') : 2
# ('@YRDSBGetOut', '@MsPizzolon') : 1
# ('@YRDSBGetOut', '@YRDSBGetOut') : 1
# ('@YRDSBGetOut', '@YRDSB') : 1
# ('@YRDSBGetOut', '@Woodbridge_PS') : 1
# ('@YRDSBGetOut', '@JuliaDeRose3') : 1
# ('@YukonEvents', '@BeWildON') : 1
# ('@YukonEvents', '@cpaws') : 1
# ('@YuppieCuntx', '@EPA') : 5
# ('@yycbike2school', '@doctormorrison') : 1
# ('@yycbike2school', '@KinderFynes') : 1
# ('@zeiss_micro', '@PlanktonPundit') : 1
# ('@ZeroSumGameNOT', '@EPA') : 1
# ('@zoebadcock', '@EPA') : 1
# ('@ZoeWeil', '@AAPremlall') : 1
# ('@ZoeWeil', '@ZoeWeil') : 1
# ('@ZoeWeil', '@HumaneEducation') : 1
# ('@ZoeWeil', '@abchome') : 1
# ('@ZohrinM', '@RangerRidley') : 1
# ('@ZwartblesIE', '@AAPremlall') : 1
# ('@zwaste', '@EPAregion2') : 1
# ('@zyngaorg', '@EduOutside') : 1

# %% [markdown]
# 1. Update: for simplicity, only include mentions of users who are in the list of nodes. This way you can set up a nested for-loop where the outer for-loop iterates over all the tweets, and the inner for-loop iterates over all the users to see if they’re mentioned.
#
#
# Woops! Did the previous before looking at the update

# %% [markdown]
# ii. Show the graph info (nodes, edges, average in- and out-degree) and network density. You should have around 3,000 edges.

# %%
print(nx.info(G))
print('\nNetwork Density\n',nx.density(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 2090
# Number of edges: 3886
# Average in degree:   1.8593
# Average out degree:   1.8593
#
# Network Density
#  0.0008900575124656151

# %% [markdown]
# iii. [Note that this step will be slow.] Calculate in-degree, out-degree, betweenness centrality, closeness centrality, and eigenvector centrality. Update each node in the graph with its values for these measures, similarly to how we did this in lab 13.

# %%
in_dict = dict(nx.in_degree_centrality(G)) 
out_dict = dict(nx.out_degree_centrality(G))
between_dict = dict(nx.betweenness_centrality(G))
close_dict = dict(nx.closeness_centrality(G))
eigen_dict = dict(nx.eigenvector_centrality(G))

# %%
nx.set_node_attributes(G, in_dict, 'in_degree')
nx.set_node_attributes(G, out_dict, 'out_degree')
nx.set_node_attributes(G, between_dict, 'between')
nx.set_node_attributes(G, close_dict, 'close')
nx.set_node_attributes(G, eigen_dict, 'eigen')

# %% [markdown]
# iv. Print out the top 20 users (nodes) ranked by each of the following metrics: in-degree, out-degree, betweenness centrality, and eigenvector centrality.

# %%
from operator import itemgetter
sorted_in = sorted(in_dict.items(), key=itemgetter(1),
reverse=True)
sorted_out = sorted(out_dict.items(), key=itemgetter(1),
reverse=True)
sorted_betweenness = sorted(between_dict.items(), key=itemgetter(1),
reverse=True)
sorted_eigen = sorted(eigen_dict.items(), key=itemgetter(1),
reverse=True)


print("\nTop 20 nodes by in-degree centrality:\n") 
for b in sorted_in[:20]:
    print(b)
print("\nTop 20 nodes by out-degree centrality:\n") 
for b in sorted_out[:20]:
    print(b)
print("\nTop 20 nodes by betweenness centrality:\n")
for b in sorted_betweenness[:20]:
    print(b)
print("\nTop 20 nodes by eigenvector centrality:\n")
for b in sorted_eigen[:20]:
    print(b)
# Out:
# Top 20 nodes by in-degree centrality:
#
# ('@RangerRidley', 0.11680229775011967)
# ('@EPA', 0.07228338918142652)
# ('@PeelSchools', 0.041646720919100044)
# ('@EnviroEducators', 0.03350885591191958)
# ('@PaulKelba', 0.028721876495931067)
# ('@KinderKids123', 0.02584968884633796)
# ('@CWF_FCF', 0.022977501196744854)
# ('@IslandWood', 0.0215414073719483)
# ('@JackSmytheFC', 0.02106270943034945)
# ('@PDSB_eco', 0.020105313547151747)
# ('@ChrisVella2', 0.019626615605552896)
# ('@NAAEEStaff', 0.019147917663954045)
# ('@stevenbody', 0.018669219722355194)
# ('@MindShiftKQED', 0.018190521780756343)
# ('@KinderFynes', 0.018190521780756343)
# ('@Sierra_BC', 0.01771182383915749)
# ('@EZECNSW', 0.01771182383915749)
# ('@CreativeSTAR', 0.01723312589755864)
# ('@ON_EcoSchools', 0.01675442795595979)
# ('@PlanktonPundit', 0.01675442795595979)
#
# Top 20 nodes by out-degree centrality:
#
# ('@RangerRidley', 0.06893250359023456)
# ('@ChrisVella2', 0.03207276208712302)
# ('@PaulKelba', 0.028243178554332216)
# ('@DavidSpencerEdu', 0.028243178554332216)
# ('@Learn_OnTheFly', 0.02537099090473911)
# ('@EZECNSW', 0.022977501196744854)
# ('@stevenbody', 0.01675442795595979)
# ('@NAAEEStaff', 0.013882240306366683)
# ('@PDSB_eco', 0.011967448539971278)
# ('@OCSBeco', 0.011488750598372427)
# ('@doctormorrison', 0.011010052656773576)
# ('@KinderKids123', 0.011010052656773576)
# ('@WestSydUFood_Ag', 0.011010052656773576)
# ('@CWF_FCF', 0.009573958831977022)
# ('@KinderFynes', 0.009095260890378171)
# ('@EnviroEducators', 0.00861656294877932)
# ('@perfinker', 0.008137865007180469)
# ('@PeelSchools', 0.008137865007180469)
# ('@AAPremlall', 0.008137865007180469)
# ('@IslandWood', 0.007659167065581618)
#
# Top 20 nodes by betweenness centrality:
#
# ('@RangerRidley', 0.06926457092831272)
# ('@PaulKelba', 0.02305338034832161)
# ('@NAAEEStaff', 0.021568492314306655)
# ('@Learn_OnTheFly', 0.018042192807863625)
# ('@IslandWood', 0.010210218163636585)
# ('@EnviroEducators', 0.009681365879073483)
# ('@ChrisVella2', 0.0092394856434953)
# ('@GEOEC', 0.008833387832237059)
# ('@DavidSpencerEdu', 0.007357529280137032)
# ('@CWF_FCF', 0.006929910613438378)
# ('@doctormorrison', 0.006575871740293452)
# ('@PDSB_eco', 0.006052860388797065)
# ('@EZECNSW', 0.006021789604642159)
# ('@KinderKids123', 0.00532432860756062)
# ('@Sierra_BC', 0.005164281484667296)
# ('@AAPremlall', 0.003927203419498162)
# ('@KinderFynes', 0.0037516346553144045)
# ('@CreativeSTAR', 0.0036335346383653184)
# ('@perfinker', 0.003514066459338086)
# ('@PeelSchools', 0.003398486329156032)
#
# Top 20 nodes by eigenvector centrality:
#
# ('@RangerRidley', 0.4109810902526576)
# ('@ChrisVella2', 0.236700759081596)
# ('@EZECNSW', 0.22571853132852288)
# ('@stevenbody', 0.21498157793910894)
# ('@PaulKelba', 0.18458707105579478)
# ('@LShenstone', 0.16929690053375093)
# ('@vivianharris45', 0.16224940888541178)
# ('@KinderKids123', 0.15040807596128533)
# ('@PeelSchools', 0.1499743001813646)
# ('@KateHelene', 0.14348917557815463)
# ('@DebHoggoz', 0.14256161835508466)
# ('@KinderFynes', 0.1347897736019906)
# ('@doctormorrison', 0.13203350539491482)
# ('@steve_papp', 0.1303421552225348)
# ('@BrewongleEEC', 0.12435839207083481)
# ('@FieldofMarsEEC', 0.12302444531894369)
# ('@CWF_FCF', 0.11444477110363942)
# ('@MikeBartlettEdu', 0.11168200819620246)
# ('@LongneckLagoon', 0.11127185601750088)
# ('@CherineSpirou', 0.10497358549446789)

# %% [markdown]
# v. In a markdown cell, discuss your observations of these 4 lists.

# %% [markdown]
# In the grand scheme of things, these numbers are super small! However, if we consider the total number of possible edges, 2090 * 2089 = 4366010, the actual number of edges is less than 1/1000th of the whole. The real density of G is 0.0008900575124656151.
#
#
# Let's take a look at @RangerRidley! If you look this man up, you will find he has many roles in environmental education:
#
# 1. Coordinator, Peel District School Board's Outdoor Ed Centres
# 2. Speaker on Value & Practices of 21st Century #OutdoorEd.
# 3. Moderator of #EnviroEd chat Wed 9-10 EST
#
# His roles, influence, and connection is very much seen throughout the above data! Mr. Ridley is the most well-connected to other well-connected #enviroEd humans. He is almost in contact with 50% of the more influential enviro-ed figures on Twitter (at least within 3/18/16 and 5/31/16).
#
# Ridley also has a diverse range of contacts. Although he is only approximately 6% between (within the shortest path) all the nodes, it shows that even those people who do not use Twitter that frequently, or tweet often about enviro-ed usually, go to and mention/contact Ridley the most.
#
# Ridley also tweeted the most within the given time interval with a 6.9% out-degree centrality measure. This would probably mean he was actively on Twitter. This would mean out of the total number of tweets about this topic (3886), he sent approximately 7% of these, or around 267 tweets.
#
# He was also referenced the most by other people who mentioned @enviroEd with a 12% in-degree centrality.

# %% [markdown]
# vi. Pick three Twitter users (nodes) for further exploration. Make a graph visualization for each of the user’s subgraphs by using http://hdlab.stanford.edu/palladio/, similar to lab 12. Save screenshots to be turned in.

# %% [markdown]
# This shows the three top Twitter users in this data from the eigenvector centrality metric and the number of followers that they have.

# %%
from IPython.display import Image
Image(filename = 'subgraphs.png')

# %% [markdown]
# vii. In a markdown cell, discuss three users you selected in terms of their graphs and assorted calculated metrics.

# %% [markdown]
# This graph represents the change in follower count for these three Twitter users with respect to time. Each node represents a moment where their follower count changed. The fact that @RangerRidley has more nodes means that at the time of each of his tweets, his number of followers has increased since the last. This may suggest that his visability and popularity is growing.

# %% [markdown]
# ##### j.  Pose an additional question or area of interest about this dataset, write code to answer it, show a visualization, and discuss your observations.

# %% [markdown]
# Is there a correlation between how many followers a user (potentially the creation of user's account) has and if the user is verified?

# %%
# Get most recent followers for each user
df = df.sort_values('Date')
df_new = df[['Screen Name', 'Followers', 'Verfied']]
df_new = df_new.drop_duplicates('Screen Name', keep='last')
df_new = pd.get_dummies(df_new, columns=['Verfied'])
df_new = df_new.sort_values('Followers', ascending=False)
df_new
# Out:
#            Screen Name  Followers  Verfied_No
# 1342         @edutopia     765634           1
# 1969      @girlshealth     587453           1
# 1596              @EPA     355308           1
# 3112    @MindShiftKQED     178761           1
# 1272  @EarthVitalSigns     165337           1
# 2180    @IsraelNewsNow     123580           1
# 4738         @Seasaver     120336           1
# 3858      @PeelSchools      93204           1
# 1162          @DMashak      90666           1
# 5484      @YosemiteNPS      85112           1
# 1643      @EPAresearch      84680           1
# 4600           @Revkin      72711           1
# 3153     @Moonbattery1      66687           1
# 613    @ChildrenNature      57680           1
# 3985     @RachelNotley      57213           1
# 939           @CWF_FCF      46467           1
# 5058  @Sustainablehero      46163           1
# 3535             @NSTA      39087           1
# 1441        @elemenous      36817           1
# 1600     @EPAgreenbldg      36219           1
# 1824      @femaregion2      31565           1
# 4702   @sarahdateechur      30793           1
# 3324  @museumofscience      29407           1
# 391     @BigHistoryPro      29256           1
# 2742       @Law1Gloria      28943           1
# 3967   @ProjectPeachUK      28275           1
# 3066      @MHEducation      26872           1
# 2265   @Jackthelad1947      23040           1
# 3029    @McGrawHillK12      22861           1
# 2262   @jackiegerstein      22311           1
# ...                ...        ...         ...
# 4816          @SKassid         11           1
# 1837   @fionammorrison         10           1
# 4773    @ShanHaldorson         10           1
# 3102    @MikeMorris24B         10           1
# 359    @beccakedenburg          9           1
# 995        @DannyBavis          9           1
# 5477   @YEKA_Envi_Solu          9           1
# 3978   @Q1moldyfruitgM          8           1
# 618   @ChristianLifeLd          8           1
# 3233    @MrsKHenderson          8           1
# 3327       @MWMScience          7           1
# 1458  @EmbarrassingPET          6           1
# 5391      @webbhalpern          6           1
# 20           @_swatik_          6           1
# 568    @CatherineJudd1          6           1
# 2418  @Kemurphyshawca1          6           1
# 136     @AgriculturalU          5           1
# 4748     @SelbieFuller          5           1
# 91         @AbshireELC          5           1
# 3546         @NygaroMy          4           1
# 3938   @plasticocean22          4           1
# 1968         @GiboJess          3           1
# 137         @AHCeagles          3           1
# 1274           @ece_fs          2           1
# 5056   @sustain_a_b0wl          1           1
# 3982    @R_EIIa_Design          1           1
# 88            @AbbyFDK          1           1
# 2043     @Greennomad73          1           1
# 5024   @StoffeyLurline          1           1
# 5309    @vickipage1332          0           1
#
# [1613 rows x 3 columns]

# %%
yes_mask = df_new['Verfied_No'] == 0
print(df_new.shape)
df_new[~yes_mask].shape
# Out:
# (1613, 3)
# (1613, 3)

# %% [markdown]
# The visualization used will be a table sorted in order by number of followers from largest to smallest. I thought that it would be interesting to see if the number of followers has an effect on if a user is verified, but according to this data, not even a user with almost 800,000 followers is verified. In fact, there is not a single account in this data set that is verified. From this data, it seems that the number of followers does not affect if a user should be Twitter verified or not.
#
# The reason we are only using a table is because I could not determine how to correctly plot this data. I tried multiple different graphs, but the parameters did not seem to work properly together. I assumed in the end it is because there does not exist a user who is verified in this dataset.
#
# I wonder if we looked at the rest of Twitter that this correlation would exist. What I could have done beforehand was to confirm what "being verified" meant. Twitter's defintion is: "An account may be verified if it is determined to be an account of public interest. Typically this includes accounts maintained by users in music, acting, fashion, government, politics, religion, journalism, media, sports, business, and other key interest areas."
#
# Although this is only about evironmental education data, it seems weird that some of the people in this data who may have other areas of influence in relation to the environment, and how the environment would not be considered under the umbrella of politics or a key interest area.
#
# According to this 2016 article online, there are some verified Twitter accounts that have less than 20,000 followers. In fact, the lowest verified user in 2016 only had four followers (https://follows.com/blog/2016/01/twitter-followers-verified). It seems music may have more pull in Twitter's eyes than genres concerning the environment and education within it.
#
# I think it is pretty crazy that someone with four followers could be considered as a verified user while someone who has approximately 800000 could not be.
